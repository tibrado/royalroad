# %%
# Imports

# %% [markdown]
# [Text Analytic](https://www.lexalytics.com/lexablog/text-analytics-functions-explained)
#
#     1. Language Identification
#     2. Tokenization
#     3. Sentence Breaking
#     4. Part of Speech Tagging
#     5. Chunking
#     6. Syntax Parsing
#     7. Sentence Chaining

# %%
# Get data intext and save as csv
file = open('../data/ongoing_fictions.txt', 'r')

# Get book info 
columns = ['title', 'tags', 'followers', 'rating', 'pages', 'views', 'chapters', 'date_last_updated']
books = []
other = []

# Add columsn to book list
books.append(columns)

# Get books 
for line in file:
    info = line.split(';')
    
    if len(info) == 8:
        info[1] = info[1].replace('|', ' ').replace('/ ', '') # Tags 
        info[2] = info[2].strip(' FOLLOWERS').replace(',', '') # Followers 
        info[4] = info[4].strip(' PAGES').replace(',', '')  # Pages 
        info[5] = info[5].strip(' VIEWS').replace(',', '')  # Views 
        info[6] = info[6].strip(' CHAPTERS').replace(',', '')  # Chapters 
        info[7] = info[7].strip('\n').replace(',', '') # date last updated 
        
        books.append(info)
    else: other.append(line)

file.close()

print(f'Size of -> books: {len(books)}, other: {len(other)}')
# Out:
# Size of -> books: 2440, other: 144

# %%
books
# Out:
# [['title',
#   'tags',
#   'followers',
#   'rating',
#   'pages',
#   'views',
#   'chapters',
#   'date_last_updated'],
#  ['Beware Of Chicken',
#   'Adventure Comedy Fantasy Romance Male Lead Martial Arts Portal Fantasy Isekai Reincarnation Xianxia ',
#   '13806',
#   '4.83',
#   '476',
#   '2623581',
#   '68',
#   'MARCH 29 2021'],
#  ['The Perfect Run',
#   'Adventure Comedy Mystery Sci-fi Anti-Hero Lead Genetically Engineered Loop Male Lead Strong Lead Super Heroes Time Travel ',
#   '8613',
#   '4.79',
#   '791',
#   '1421991',
#   '68',
#   'MARCH 27 2021'],
#  ['Kairos: A Greek Myth LitRPG',
#   'Action Adventure Fantasy Anti-Hero Lead High Fantasy LitRPG Male Lead Mythos Progression Ruling Class Strategy ',
#   '3042',
#   '4.82',
#   '157',
#   '92442',
#   '12',
#   'MARCH 27 2021'],
#  ['Vigor Mortis',
#   'Adventure Fantasy Horror Female Lead High Fantasy Magic Progression ',
#   '4931',
#   '4.78',
#   '380',
#   '376463',
#   '35',
#   'MARCH 29 2021'],
#  ['A Journey of Black and Red',
#   'Action Adventure Fantasy Historical Female Lead Urban Fantasy Villainous Lead ',
#   '6420',
#   '4.73',
#   '2006',
#   '1608082',
#   '107',
#   'MARCH 26 2021'],
#  ['Borne of Caution',
#   'Adventure Drama Fantasy Male Lead Multiple Lead Characters Non-Human lead Portal Fantasy Isekai Supernatural Urban Fantasy ',
#   '4699',
#   '4.74',
#   '594',
#   '407873',
#   '25',
#   'MARCH 14 2021'],
#  ['Seaborn',
#   'Adventure Fantasy GameLit LitRPG Magic ',
#   '8189',
#   '4.72',
#   '790',
#   '1132343',
#   '49',
#   'MARCH 28 2021'],
#  ['RE: Monarch',
#   'Adventure Fantasy Mystery Psychological Grimdark High Fantasy Loop Magic Male Lead Martial Arts Progression Reincarnation Strategy Time Travel ',
#   '4036',
#   '4.72',
#   '736',
#   '746956',
#   '78',
#   'MARCH 26 2021'],
#  ['Tower of Somnus',
#   'Action Adventure Fantasy Sci-fi Cyberpunk Female Lead GameLit LitRPG Magic Urban Fantasy ',
#   '6020',
#   '4.71',
#   '888',
#   '1119547',
#   '73',
#   'MARCH 28 2021'],
#  ['Prophecy Approved Companion',
#   'Adventure Comedy Fantasy Satire Female Lead GameLit High Fantasy LitRPG Magic Non-Human lead Virtual Reality ',
#   '2655',
#   '4.73',
#   '505',
#   '467594',
#   '67',
#   'MARCH 25 2021'],
#  ['Azarinth Healer',
#   'Action Adventure Fantasy Female Lead LitRPG Magic ',
#   '15766',
#   '4.67',
#   '7350',
#   '25732740',
#   '655',
#   'MARCH 27 2021'],
#  ['Virtuous Sons: A Greco Roman Xianxia',
#   'Adventure Comedy Fantasy Tragedy Attractive MC Low Fantasy Magic Male Lead Martial Arts Multiple Lead Characters Mythos Progression Secret Identity Slice of Life Strong Lead Supernatural War and Military Wuxia Xianxia ',
#   '428',
#   '4.88',
#   '95',
#   '11288',
#   '13',
#   'MARCH 28 2021'],
#  ['Romantically Apocalyptic',
#   'Adventure Comedy Horror Sci-fi Anti-Hero Lead Artificial Intelligence Cyberpunk Dystopia Female Lead Male Lead Multiple Lead Characters Post Apocalyptic Strong Lead Super Heroes Supernatural Time Travel War and Military ',
#   '1111',
#   '4.68',
#   '344',
#   '238968',
#   '132',
#   'MARCH 24 2021'],
#  ['Shade Touched',
#   'Action Adventure Fantasy Female Lead High Fantasy Magic Non-Human lead Slice of Life ',
#   '6357',
#   '4.68',
#   '572',
#   '1046806',
#   '78',
#   'MARCH 08 2021'],
#  ["Dungeon Crawler Carl Book 3: The Dungeon Anarchist's Cookbook",
#   'Action Adventure Comedy Fantasy Dungeon GameLit Grimdark LitRPG Low Fantasy Magic Male Lead Non-Human lead Post Apocalyptic Strategy Strong Lead Supernatural ',
#   '7115',
#   '4.66',
#   '1000',
#   '939931',
#   '60',
#   'MARCH 27 2021'],
#  ['The Power of Ten, Book Three : The Human Race',
#   'Action Adventure Fantasy Female Lead GameLit Gender Bender LitRPG Magic Mythos Strong Lead Urban Fantasy War and Military ',
#   '538',
#   '4.8',
#   '1950',
#   '388169',
#   '246',
#   'MARCH 29 2021'],
#  ['Path of the Dragon Mage: Exiled',
#   'Action Adventure Drama Fantasy GameLit High Fantasy LitRPG Male Lead Progression Secret Identity Virtual Reality ',
#   '5410',
#   '4.69',
#   '235',
#   '338068',
#   '27',
#   'MARCH 26 2021'],
#  ['Cinnamon Bun',
#   'Action Adventure Comedy Fantasy Female Lead LitRPG Magic Portal Fantasy Isekai ',
#   '4754',
#   '4.67',
#   '1367',
#   '2050389',
#   '183',
#   'MARCH 29 2021'],
#  ["Stray Cat Strut \u2060— A Young Lady's Journey to Becoming a Pop-Up Samurai",
#   'Action Sci-fi Artificial Intelligence Cyberpunk Female Lead GameLit LitRPG Soft Sci-fi ',
#   '3736',
#   '4.69',
#   '656',
#   '1006869',
#   '123',
#   'MARCH 25 2021'],
#  ['The Path of Ascension',
#   'Action Adventure Fantasy Dungeon High Fantasy LitRPG Magic Male Lead Martial Arts Progression Soft Sci-fi Strong Lead Xianxia ',
#   '4102',
#   '4.7',
#   '343',
#   '157931',
#   '17',
#   'MARCH 29 2021'],
#  ['Forge of Destiny',
#   'Action Adventure Drama Fantasy Female Lead Magic Martial Arts Slice of Life Xianxia ',
#   '7606',
#   '4.65',
#   '2842',
#   '6982895',
#   '327',
#   'MARCH 27 2021'],
#  ['A Lonely Dungeon',
#   'Adventure Fantasy Mystery Dungeon GameLit Grimdark High Fantasy LitRPG Magic Non-Human lead Post Apocalyptic ',
#   '3129',
#   '4.66',
#   '213',
#   '305211',
#   '24',
#   'MARCH 07 2021'],
#  ['The Wandering Inn',
#   'Adventure Fantasy Female Lead LitRPG Magic Multiple Lead Characters Portal Fantasy Isekai ',
#   '7939',
#   '4.63',
#   '26493',
#   '10712885',
#   '490',
#   'MARCH 23 2021'],
#  ['The Calamity of a Reborn Witch',
#   'Drama Fantasy Psychological Tragedy Female Lead Grimdark High Fantasy Magic Multiple Lead Characters Portal Fantasy Isekai Reincarnation Ruling Class Secret Identity Strategy Strong Lead ',
#   '2167',
#   '4.74',
#   '1374',
#   '883098',
#   '178',
#   'MARCH 27 2021'],
#  ['Blue Core',
#   'Action Adventure Fantasy Dungeon LitRPG Magic Non-Human lead ',
#   '10439',
#   '4.63',
#   '2059',
#   '5285855',
#   '169',
#   'MARCH 26 2021'],
#  ['Wildcards: Book One - The Dread Pirate',
#   'Action Adventure Fantasy Sci-fi Anti-Hero Lead Cyberpunk GameLit LitRPG Male Lead Multiple Lead Characters Strategy Virtual Reality ',
#   '2857',
#   '4.67',
#   '525',
#   '430843',
#   '48',
#   'MARCH 25 2021'],
#  ['Magic-Smithing',
#   'Action Adventure Fantasy Female Lead GameLit Gender Bender High Fantasy Magic Reincarnation Slice of Life Strong Lead ',
#   '10632',
#   '4.62',
#   '1237',
#   '2087406',
#   '69',
#   'MARCH 25 2021'],
#  ['The House Witch',
#   'Adventure Comedy Fantasy Romance High Fantasy Magic Male Lead ',
#   '4432',
#   '4.65',
#   '715',
#   '645398',
#   '66',
#   'MARCH 26 2021'],
#  ['The Obsidian Core',
#   'Action Adventure Fantasy Dungeon GameLit High Fantasy LitRPG Low Fantasy Magic Non-Human lead Strategy Supernatural ',
#   '1992',
#   '4.72',
#   '167',
#   '81773',
#   '16',
#   'MARCH 26 2021'],
#  ['The Menocht Loop',
#   'Action Adventure Fantasy Psychological High Fantasy Loop Magic Male Lead Progression Strategy Strong Lead Urban Fantasy ',
#   '7944',
#   '4.62',
#   '1340',
#   '2866616',
#   '150',
#   'MARCH 29 2021'],
#  ['Salvos',
#   'Action Adventure Comedy Fantasy Female Lead GameLit High Fantasy LitRPG Magic Portal Fantasy Isekai Progression Strong Lead ',
#   '7065',
#   '4.63',
#   '832',
#   '1734907',
#   '116',
#   'MARCH 29 2021'],
#  ["The Eagle's Flight",
#   'Adventure Drama Fantasy Historical High Fantasy Multiple Lead Characters Ruling Class Strategy Supernatural War and Military ',
#   '1356',
#   '4.71',
#   '2496',
#   '636979',
#   '177',
#   'MARCH 24 2021'],
#  ['Rise of the Archon (Rewrite)',
#   'Action Adventure Fantasy Magic Male Lead Martial Arts School Life Strong Lead Supernatural Xianxia ',
#   '888',
#   '4.86',
#   '115',
#   '21379',
#   '12',
#   'MARCH 27 2021'],
#  ['Vaudevillain',
#   'Action Comedy Sci-fi GameLit LitRPG Male Lead Super Heroes Villainous Lead Virtual Reality ',
#   '6131',
#   '4.61',
#   '1366',
#   '2327659',
#   '203',
#   'MARCH 29 2021'],
#  ['Rebirth in a Magical World',
#   'Action Adventure Comedy Fantasy Magic Male Lead Reincarnation School Life ',
#   '3825',
#   '4.64',
#   '1058',
#   '1478552',
#   '103',
#   'MARCH 23 2021'],
#  ['Sylver Seeker',
#   'Action Adventure Fantasy LitRPG Magic Male Lead Reincarnation ',
#   '8151',
#   '4.6',
#   '1183',
#   '1351643',
#   '67',
#   'MARCH 28 2021'],
#  ['Ave Xia Rem Y',
#   'Action Adventure Fantasy Harem Male Lead Martial Arts Supernatural Xianxia ',
#   '3139',
#   '4.64',
#   '1191',
#   '1321989',
#   '130',
#   'MARCH 29 2021'],
#  ['Artificial Jelly',
#   'Adventure Fantasy Sci-fi Tragedy Dungeon Female Lead GameLit LitRPG Low Fantasy Non-Human lead Soft Sci-fi Strategy Virtual Reality ',
#   '4799',
#   '4.6',
#   '107',
#   '204647',
#   '19',
#   'MARCH 26 2021'],
#  ['Knight and Smith',
#   'Action Adventure Fantasy Romance High Fantasy Male Lead Strong Lead ',
#   '2936',
#   '4.63',
#   '1143',
#   '328656',
#   '38',
#   'MARCH 26 2021'],
#  ['Fantasia',
#   'Adventure Comedy Fantasy Romance Female Lead LitRPG Slice of Life Strong Lead Virtual Reality ',
#   '4836',
#   '4.58',
#   '928',
#   '2915924',
#   '89',
#   'MARCH 17 2021'],
#  ['Delve',
#   'Action Adventure Drama Fantasy High Fantasy LitRPG Magic Male Lead Portal Fantasy Isekai Progression Slice of Life Strong Lead ',
#   '15639',
#   '4.58',
#   '2606',
#   '7285127',
#   '140',
#   'MARCH 27 2021'],
#  ["The Great Core's Paradox",
#   'Action Adventure Fantasy GameLit LitRPG Loop Magic Non-Human lead Progression ',
#   '2247',
#   '4.69',
#   '130',
#   '122786',
#   '24',
#   'MARCH 27 2021'],
#  ['Pith',
#   'Action Adventure Fantasy Psychological Gender Bender High Fantasy Magic Multiple Lead Characters Strategy ',
#   '816',
#   '4.71',
#   '1959',
#   '112739',
#   '68',
#   'MARCH 24 2021'],
#  ['Infinite Realm: Monsters & Legends',
#   'Action Adventure Fantasy Anti-Hero Lead Female Lead GameLit High Fantasy LitRPG Male Lead Martial Arts Multiple Lead Characters Portal Fantasy Isekai Progression Strong Lead Xianxia ',
#   '3064',
#   '4.62',
#   '3054',
#   '2498498',
#   '264',
#   'MARCH 29 2021'],
#  ['Metaworld Chronicles',
#   'Action Adventure Contemporary Fantasy Female Lead Magic Reincarnation Slice of Life Strong Lead ',
#   '9528',
#   '4.58',
#   '6590',
#   '14002249',
#   '422',
#   'MARCH 28 2021'],
#  ['The Courting of Life and Death',
#   'Fantasy Historical Horror Romance Anti-Hero Lead Female Lead High Fantasy Magic Male Lead Multiple Lead Characters Mythos Non-Human lead Ruling Class Slice of Life Steampunk Strong Lead Supernatural ',
#   '614',
#   '4.6',
#   '492',
#   '88495',
#   '57',
#   'MARCH 29 2021'],
#  ['Summon Imp!',
#   'Adventure Fantasy Anti-Hero Lead High Fantasy Low Fantasy Magic Non-Human lead Slice of Life ',
#   '2747',
#   '4.63',
#   '500',
#   '399167',
#   '51',
#   'MARCH 21 2021'],
#  ['The Law of Averages',
#   'Adventure Comedy Fantasy Sci-fi Male Lead Portal Fantasy Isekai Slice of Life Super Heroes ',
#   '2866',
#   '4.62',
#   '998',
#   '1558152',
#   '126',
#   'MARCH 26 2021'],
#  ['First Contact',
#   'Action Adventure Sci-fi Cyberpunk Multiple Lead Characters Non-Human lead Space Opera War and Military ',
#   '1589',
#   '4.65',
#   '5049',
#   '1759574',
#   '477',
#   'MARCH 29 2021'],
#  ['Demesne',
#   'Adventure Comedy Fantasy Dungeon Female Lead High Fantasy Magic Ruling Class Slice of Life Supernatural ',
#   '578',
#   '4.78',
#   '150',
#   '22881',
#   '18',
#   'MARCH 28 2021'],
#  ['Digital Marine',
#   'Action Adventure Sci-fi Female Lead LitRPG Space Opera Virtual Reality War and Military ',
#   '2191',
#   '4.64',
#   '1444',
#   '689601',
#   '84',
#   'MARCH 29 2021'],
#  ['Chrysalis',
#   'Adventure Comedy Fantasy LitRPG Magic Non-Human lead Reincarnation ',
#   '9610',
#   '4.56',
#   '3470',
#   '18539912',
#   '718',
#   'MARCH 25 2021'],
#  ['Lever Action',
#   'Action Adventure Fantasy Female Lead Post Apocalyptic Progression Steampunk Technologically Engineered ',
#   '642',
#   '4.84',
#   '97',
#   '20901',
#   '19',
#   'MARCH 29 2021'],
#  ['New Life of a Summoned Demoness',
#   'Action Adventure Fantasy Female Lead LitRPG Magic Portal Fantasy Isekai Progression Strong Lead ',
#   '4897',
#   '4.58',
#   '372',
#   '593288',
#   '52',
#   'MARCH 21 2021'],
#  ['The Primal Hunter',
#   'Action Adventure Fantasy Psychological Anti-Hero Lead High Fantasy LitRPG Magic Male Lead Mythos Progression Ruling Class Strong Lead Supernatural ',
#   '9388',
#   '4.53',
#   '1596',
#   '3476306',
#   '158',
#   'MARCH 29 2021'],
#  ["Ar'Kendrithyst",
#   'Adventure Fantasy High Fantasy LitRPG Magic Portal Fantasy Isekai Slice of Life ',
#   '3019',
#   '4.57',
#   '5281',
#   '1704314',
#   '191',
#   'MARCH 28 2021'],
#  ["Eterna's Source",
#   'Adventure Fantasy Romance Female Lead Magic Male Lead Multiple Lead Characters ',
#   '1237',
#   '4.65',
#   '272',
#   '244643',
#   '28',
#   'MARCH 03 2021'],
#  ['Chronicles of the last Leïn',
#   'Action Adventure Drama Fantasy Female Lead High Fantasy Magic Martial Arts Progression Secret Identity Slice of Life Strategy Strong Lead ',
#   '772',
#   '4.67',
#   '687',
#   '124890',
#   '55',
#   'MARCH 26 2021'],
#  ['Beneath the Dragoneye Moons',
#   'Action Adventure Fantasy Female Lead High Fantasy LitRPG Magic Portal Fantasy Isekai Progression Reincarnation Strong Lead Supernatural ',
#   '5662',
#   '4.53',
#   '1444',
#   '1887971',
#   '150',
#   'MARCH 24 2021'],
#  ['Magnus',
#   'Action Adventure Fantasy Sci-fi Anti-Hero Lead Genetically Engineered Grimdark LitRPG Magic Male Lead Portal Fantasy Isekai Soft Sci-fi Strong Lead Technologically Engineered ',
#   '2273',
#   '4.63',
#   '1187',
#   '927872',
#   '145',
#   'MARCH 28 2021'],
#  ['An Unbound Soul',
#   'Adventure Fantasy Dungeon GameLit High Fantasy LitRPG Magic Male Lead Portal Fantasy Isekai Progression Reincarnation Slice of Life Supernatural ',
#   '2140',
#   '4.64',
#   '360',
#   '196650',
#   '43',
#   'MARCH 27 2021'],
#  ['Isekai Mother',
#   'Action Adventure Fantasy Psychological Anti-Hero Lead Female Lead High Fantasy LitRPG Magic Portal Fantasy Isekai Secret Identity Strong Lead ',
#   '2123',
#   '4.61',
#   '142',
#   '69831',
#   '13',
#   'MARCH 08 2021'],
#  ['Dead Tired',
#   'Comedy Fantasy Satire Anti-Hero Lead LitRPG Magic Male Lead Non-Human lead Strong Lead Villainous Lead Wuxia Xianxia ',
#   '4511',
#   '4.56',
#   '482',
#   '766312',
#   '67',
#   'MARCH 25 2021'],
#  ["Who Says This OL Can't Become A Splendid Slime!?",
#   'Adventure Fantasy Anti-Hero Lead Female Lead High Fantasy LitRPG Magic Non-Human lead Portal Fantasy Isekai Reincarnation ',
#   '4737',
#   '4.54',
#   '763',
#   '883705',
#   '52',
#   'MARCH 10 2021'],
#  ['The Last Human',
#   'Action Adventure Fantasy Sci-fi Anti-Hero Lead Cyberpunk Dystopia First Contact Genetically Engineered Low Fantasy Male Lead Multiple Lead Characters Mythos Non-Human lead Portal Fantasy Isekai Post Apocalyptic Progression Ruling Class Soft Sci-fi ',
#   '2152',
#   '4.62',
#   '335',
#   '210682',
#   '40',
#   'MARCH 23 2021'],
#  ['Eldritch Entity On A Journey Of Self-Discovery',
#   'Adventure Fantasy High Fantasy Magic Male Lead Mythos ',
#   '1078',
#   '4.68',
#   '97',
#   '50635',
#   '16',
#   'MARCH 06 2021'],
#  ['Katalepsis',
#   'Contemporary Fantasy Horror Romance Female Lead Magic Supernatural Urban Fantasy ',
#   '910',
#   '4.63',
#   '2909',
#   '230554',
#   '118',
#   'MARCH 26 2021'],
#  ['The Most Overpowered Floofer',
#   'Action Adventure Comedy Fantasy GameLit High Fantasy LitRPG Magic Male Lead Non-Human lead Portal Fantasy Isekai Reincarnation ',
#   '1026',
#   '4.64',
#   '115',
#   '95998',
#   '23',
#   'MARCH 27 2021'],
#  ['Brewer King',
#   'Adventure Fantasy GameLit Low Fantasy Male Lead Portal Fantasy Isekai ',
#   '2373',
#   '4.58',
#   '696',
#   '235921',
#   '43',
#   'MARCH 27 2021'],
#  ['Human Altered',
#   'Comedy Sci-fi War and Military ',
#   '948',
#   '4.63',
#   '656',
#   '212071',
#   '77',
#   'MARCH 26 2021'],
#  ['Tree of Aeons (An isekai story)',
#   'Action Adventure Fantasy Anti-Hero Lead GameLit Magic Non-Human lead Portal Fantasy Isekai Reincarnation Ruling Class Strong Lead ',
#   '6065',
#   '4.53',
#   '1701',
#   '3063082',
#   '140',
#   'MARCH 23 2021'],
#  ['Dreams Come True',
#   'Adventure Fantasy Psychological Sci-fi Magic Male Lead Portal Fantasy Isekai Reincarnation School Life Slice of Life Supernatural ',
#   '2891',
#   '4.55',
#   '1250',
#   '1480426',
#   '122',
#   'MARCH 23 2021'],
#  ['The Daily Grind',
#   'Action Adventure Comedy Contemporary Supernatural ',
#   '3467',
#   '4.52',
#   '2836',
#   '2082388',
#   '135',
#   'MARCH 27 2021'],
#  ['Power Overwhelming',
#   'Action Drama Fantasy Romance Female Lead Magic Reincarnation Strong Lead Xianxia ',
#   '3180',
#   '4.57',
#   '826',
#   '518108',
#   '61',
#   'MARCH 28 2021'],
#  ['Defiance of the Fall',
#   'Action Adventure Fantasy Sci-fi LitRPG Magic Male Lead Post Apocalyptic Strong Lead Supernatural Xianxia ',
#   '12125',
#   '4.48',
#   '4778',
#   '18657434',
#   '586',
#   'MARCH 29 2021'],
#  ['Eight',
#   'Action Adventure Comedy Fantasy High Fantasy LitRPG Magic Male Lead Portal Fantasy Isekai Reincarnation ',
#   '4541',
#   '4.52',
#   '971',
#   '1379897',
#   '106',
#   'MARCH 14 2021'],
#  ['The Pen Is Mightier',
#   'Action Adventure Drama Fantasy Dungeon GameLit Low Fantasy Magic Male Lead Progression Supernatural ',
#   '2500',
#   '4.56',
#   '535',
#   '396264',
#   '72',
#   'MARCH 26 2021'],
#  ['Rise of the Mechanar',
#   'Action Adventure Fantasy Grimdark High Fantasy LitRPG Magic Male Lead Ruling Class Strategy Strong Lead ',
#   '1647',
#   '4.59',
#   '387',
#   '144786',
#   '30',
#   'MARCH 03 2021'],
#  ['Web of Secrets [Modern Cultivation]',
#   'Action Adventure Fantasy Mystery Anti-Hero Lead Female Lead High Fantasy Magic Male Lead Martial Arts Multiple Lead Characters Progression School Life Urban Fantasy Wuxia Xianxia ',
#   '1993',
#   '4.6',
#   '166',
#   '94111',
#   '21',
#   'MARCH 26 2021'],
#  ['Ursus Ex Machina',
#   'Action Adventure Comedy Fantasy High Fantasy Magic Male Lead Steampunk Strong Lead ',
#   '802',
#   '4.75',
#   '269',
#   '36018',
#   '17',
#   'MARCH 25 2021'],
#  ['Yora Chronicles',
#   'Action Adventure Fantasy Tragedy Anti-Hero Lead Female Lead High Fantasy Magic Male Lead Multiple Lead Characters Non-Human lead Secret Identity Slice of Life Strong Lead ',
#   '884',
#   '4.67',
#   '1921',
#   '316648',
#   '62',
#   'MARCH 06 2021'],
#  ["A Demon's Tail",
#   'Action Fantasy Romance Female Lead Magic Male Lead Multiple Lead Characters Non-Human lead Reincarnation Strong Lead Supernatural Villainous Lead ',
#   '2495',
#   '4.57',
#   '860',
#   '414956',
#   '70',
#   'MARCH 29 2021'],
#  ['The Abyssal Dungeon',
#   'Adventure Fantasy Anti-Hero Lead Dungeon Female Lead GameLit High Fantasy Magic Male Lead Multiple Lead Characters Non-Human lead Reader interactive Slice of Life Strong Lead ',
#   '4274',
#   '4.51',
#   '926',
#   '2199357',
#   '122',
#   'MARCH 13 2021'],
#  ['Dungeon of Seasons',
#   'Action Adventure Fantasy Dungeon GameLit High Fantasy Magic Multiple Lead Characters ',
#   '2197',
#   '4.56',
#   '449',
#   '312225',
#   '47',
#   'MARCH 22 2021'],
#  ['Worth the Candle',
#   'Action Adventure Drama Fantasy GameLit High Fantasy LitRPG Magic Male Lead Portal Fantasy Isekai ',
#   '3440',
#   '4.51',
#   '5345',
#   '1681997',
#   '228',
#   'MARCH 23 2021'],
#  ['The Agartha Loop',
#   'Action Drama Fantasy Romance Female Lead Loop Magic Mythos Portal Fantasy Isekai Progression School Life Slice of Life Supernatural Time Travel War and Military ',
#   '1265',
#   '4.65',
#   '178',
#   '73636',
#   '25',
#   'MARCH 25 2021'],
#  ['The New World',
#   'Action Adventure Mystery Grimdark LitRPG Magic Strategy Strong Lead ',
#   '10327',
#   '4.47',
#   '4143',
#   '10847332',
#   '300',
#   'MARCH 28 2021'],
#  ['Sexy Space Babes',
#   'Action Adventure Comedy Sci-fi First Contact Harem Male Lead Space Opera ',
#   '3170',
#   '4.52',
#   '167',
#   '107508',
#   '14',
#   'MARCH 23 2021'],
#  ['Tales of Destiny',
#   'Short Story Magic Wuxia Xianxia ',
#   '346',
#   '4.88',
#   '143',
#   '34447',
#   '21',
#   'MARCH 24 2021'],
#  ['Spiteful Healer',
#   'Action Adventure Fantasy Romance GameLit High Fantasy LitRPG Magic Male Lead Slice of Life Strategy Strong Lead Virtual Reality ',
#   '1808',
#   '4.56',
#   '432',
#   '226870',
#   '46',
#   'MARCH 23 2021'],
#  ['Harbinger of Destruction (an EVP LitRPG)',
#   'Fantasy GameLit LitRPG Male Lead Strong Lead ',
#   '1467',
#   '4.59',
#   '281',
#   '150300',
#   '39',
#   'MARCH 28 2021'],
#  ['The Beast and The Swallow',
#   'Action Fantasy Historical Romance Female Lead High Fantasy Low Fantasy Male Lead Multiple Lead Characters Ruling Class Strong Lead Supernatural War and Military ',
#   '353',
#   '4.68',
#   '546',
#   '47380',
#   '64',
#   'MARCH 28 2021'],
#  ['The Genesis System',
#   'Action Adventure Fantasy LitRPG Magic Strategy Supernatural ',
#   '4479',
#   '4.48',
#   '929',
#   '3003398',
#   '115',
#   'MARCH 25 2021'],
#  ["The Terrarian's Reincarnation",
#   'Action Adventure Fantasy High Fantasy Magic Male Lead Portal Fantasy Isekai Reincarnation Slice of Life Strong Lead ',
#   '575',
#   '4.65',
#   '233',
#   '96850',
#   '45',
#   'MARCH 28 2021'],
#  ['Saga of the Soul Dungeon - Old',
#   'Action Adventure Fantasy Psychological Dungeon GameLit High Fantasy LitRPG Magic Male Lead Multiple Lead Characters Non-Human lead Progression Reincarnation Strategy Strong Lead ',
#   '1952',
#   '4.51',
#   '312',
#   '411529',
#   '44',
#   'MARCH 15 2021'],
#  ['Me? Dragon',
#   'Action Adventure Fantasy Anti-Hero Lead Female Lead GameLit High Fantasy LitRPG Magic Multiple Lead Characters Non-Human lead ',
#   '2260',
#   '4.52',
#   '216',
#   '252230',
#   '35',
#   'MARCH 28 2021'],
#  ['Dial (Ben 10/MCU SI)',
#   'Action Adventure Comedy Sci-fi Male Lead Slice of Life Super Heroes ',
#   '1597',
#   '4.55',
#   '2455',
#   '1124921',
#   '139',
#   'MARCH 21 2021'],
#  ['The Fragmented Six (Six Chances)',
#   'Drama Fantasy Mystery Psychological Anti-Hero Lead Female Lead Male Lead Multiple Lead Characters Progression Ruling Class Secret Identity Soft Sci-fi Strategy Strong Lead War and Military ',
#   '283',
#   '4.69',
#   '1682',
#   '58929',
#   '98',
#   'MARCH 22 2021'],
#  ['Interdimensional Garbage Merchant',
#   'Action Adventure Sci-fi Female Lead LitRPG Post Apocalyptic Slice of Life ',
#   '2607',
#   '4.49',
#   '1574',
#   '766747',
#   '121',
#   'MARCH 26 2021'],
#  ['Wooden Gem',
#   'Action Adventure Drama Fantasy Attractive MC Female Lead Gender Bender High Fantasy LitRPG Magic Multiple Lead Characters Mythos Portal Fantasy Isekai Slice of Life ',
#   '2204',
#   '4.49',
#   '914',
#   '352521',
#   '65',
#   'MARCH 20 2021'],
#  ['The Storm King',
#   'Action Adventure Fantasy Harem Magic Male Lead Secret Identity Strategy Strong Lead Supernatural ',
#   '3892',
#   '4.47',
#   '5145',
#   '4778801',
#   '540',
#   'MARCH 29 2021'],
#  ['Inexorable Chaos',
#   'Action Adventure Comedy Fantasy Anti-Hero Lead Dungeon Female Lead GameLit Grimdark Harem High Fantasy LitRPG Magic Male Lead Martial Arts Multiple Lead Characters Mythos Non-Human lead Portal Fantasy Isekai ',
#   '4813',
#   '4.44',
#   '1722',
#   '2042925',
#   '172',
#   'MARCH 23 2021'],
#  ['Star Wars: A Penumbral Path',
#   'Action Adventure Fantasy Sci-fi Female Lead Magic Male Lead Martial Arts Multiple Lead Characters Space Opera ',
#   '193',
#   '4.85',
#   '525',
#   '26775',
#   '28',
#   'MARCH 16 2021'],
#  ['Villainous',
#   'Adventure Drama Fantasy Female Lead High Fantasy LitRPG Magic Non-Human lead Portal Fantasy Isekai Reincarnation Secret Identity Strong Lead ',
#   '1957',
#   '4.51',
#   '586',
#   '349580',
#   '53',
#   'MARCH 22 2021'],
#  ['Nanocultivation Chronicles: Trials of Lilijoy',
#   'Fantasy Sci-fi Female Lead GameLit LitRPG Post Apocalyptic ',
#   '1175',
#   '4.54',
#   '2208',
#   '704822',
#   '174',
#   'MARCH 21 2021'],
#  ['Touch',
#   'Adventure Drama Fantasy Psychological Female Lead Low Fantasy Magic Male Lead Multiple Lead Characters School Life Secret Identity Strategy Strong Lead Supernatural Urban Fantasy ',
#   '630',
#   '4.54',
#   '836',
#   '383690',
#   '103',
#   'MARCH 16 2021'],
#  ['Two Worlds',
#   'Action Adventure Sci-fi Anti-Hero Lead Multiple Lead Characters Strategy ',
#   '1671',
#   '4.54',
#   '3187',
#   '2394722',
#   '371',
#   'MARCH 22 2021'],
#  ['Eyes of the Asura: A Superhero GameLit',
#   'Action Drama Fantasy Sci-fi GameLit Low Fantasy Male Lead Mythos Progression Super Heroes Supernatural Urban Fantasy ',
#   '1522',
#   '4.55',
#   '406',
#   '187409',
#   '54',
#   'MARCH 29 2021'],
#  ['Emmy And Me',
#   'Contemporary Drama Fantasy Romance Female Lead School Life Slice of Life Strong Lead ',
#   '407',
#   '4.66',
#   '1054',
#   '68344',
#   '68',
#   'MARCH 27 2021'],
#  ['Oasis',
#   'Fantasy Dungeon GameLit High Fantasy LitRPG Magic Male Lead Multiple Lead Characters Non-Human lead Supernatural ',
#   '1322',
#   '4.57',
#   '237',
#   '110420',
#   '39',
#   'MARCH 29 2021'],
#  ['A Stranger in Sorcererstown (The Stranger Trails Saga)',
#   'Action Adventure Fantasy Anti-Hero Lead Magic Strong Lead ',
#   '631',
#   '4.55',
#   '937',
#   '124056',
#   '76',
#   'MARCH 26 2021'],
#  ['Chasing Experience',
#   'Action Adventure Fantasy Magic Male Lead Martial Arts Portal Fantasy Isekai Reincarnation Xianxia ',
#   '1415',
#   '4.49',
#   '908',
#   '281468',
#   '88',
#   'MARCH 25 2021'],
#  ['The Last Game',
#   'Action Adventure Fantasy GameLit LitRPG Magic Male Lead Progression Time Travel ',
#   '2136',
#   '4.5',
#   '237',
#   '91044',
#   '17',
#   'MARCH 29 2021'],
#  ['Life of Numbers',
#   'Action Adventure Contemporary Fantasy LitRPG Male Lead Post Apocalyptic Supernatural ',
#   '2739',
#   '4.46',
#   '798',
#   '714369',
#   '80',
#   'MARCH 05 2021'],
#  ['Lone: The Wanderer [Rewrite]',
#   'Action Adventure Fantasy Romance Dungeon High Fantasy LitRPG Magic Male Lead Non-Human lead Portal Fantasy Isekai Progression Ruling Class Secret Identity Strong Lead Supernatural ',
#   '1701',
#   '4.51',
#   '928',
#   '434081',
#   '120',
#   'MARCH 28 2021'],
#  ['When Immortal Ascension Fails Time Travel to Try Again',
#   'Comedy Fantasy Satire Short Story Female Lead Male Lead Multiple Lead Characters Portal Fantasy Isekai Progression Reincarnation Strong Lead Time Travel Xianxia ',
#   '674',
#   '4.64',
#   '147',
#   '52054',
#   '33',
#   'MARCH 26 2021'],
#  ['Demon Legacy',
#   'Action Adventure Fantasy Sci-fi Anti-Hero Lead Attractive MC Dungeon High Fantasy LitRPG Male Lead Martial Arts Non-Human lead Portal Fantasy Isekai Progression Reincarnation School Life Soft Sci-fi Space Opera Strong Lead ',
#   '2236',
#   '4.51',
#   '136',
#   '89537',
#   '18',
#   'MARCH 28 2021'],
#  ["In Loki's Honor (season II)",
#   'Adventure Fantasy Psychological Female Lead Gender Bender Grimdark High Fantasy LitRPG Magic Portal Fantasy Isekai Reincarnation Strong Lead ',
#   '2192',
#   '4.46',
#   '2479',
#   '1284463',
#   '257',
#   'MARCH 29 2021'],
#  ['Spire Dweller',
#   'Adventure Fantasy Female Lead GameLit Progression Xianxia ',
#   '2103',
#   '4.5',
#   '256',
#   '100960',
#   '19',
#   'MARCH 20 2021'],
#  ['Genesis Wave',
#   'Adventure Fantasy Sci-fi GameLit LitRPG Magic Male Lead Progression Slice of Life Strategy ',
#   '1935',
#   '4.49',
#   '401',
#   '222045',
#   '45',
#   'MARCH 19 2021'],
#  ['Rise of the Archon',
#   'Action Adventure Fantasy High Fantasy Magic Male Lead Martial Arts School Life Strong Lead Xianxia ',
#   '939',
#   '4.55',
#   '908',
#   '360513',
#   '108',
#   'MARCH 06 2021'],
#  ['The Oscillation (No Swearing)',
#   'Action Drama Psychological Dungeon Female Lead GameLit Low Fantasy Magic Martial Arts Multiple Lead Characters Mythos Non-Human lead Portal Fantasy Isekai Slice of Life Super Heroes Supernatural Urban Fantasy ',
#   '260',
#   '4.61',
#   '1921',
#   '174315',
#   '123',
#   'MARCH 29 2021'],
#  ['Greg Veder vs The World',
#   'Action Adventure Comedy LitRPG Male Lead Progression Secret Identity Super Heroes Supernatural ',
#   '1580',
#   '4.49',
#   '1480',
#   '939656',
#   '99',
#   'MARCH 21 2021'],
#  ['The Future That Never Was: KITTY KITTY',
#   'Action Satire Sci-fi Short Story Anti-Hero Lead Artificial Intelligence Cyberpunk Dystopia Female Lead Gender Bender Genetically Engineered Grimdark Hard Sci-fi Male Lead Martial Arts Multiple Lead Characters Non-Human lead Progression Reader interactive ',
#   '102',
#   '4.75',
#   '176',
#   '12966',
#   '13',
#   'MARCH 14 2021'],
#  ['I Am Going To Die (In This Game-Like Dimension)',
#   'Adventure Romance Female Lead LitRPG Magic Portal Fantasy Isekai ',
#   '2820',
#   '4.42',
#   '837',
#   '402880',
#   '91',
#   'MARCH 26 2021'],
#  ['The Last Prayer',
#   'Action Drama Harem ',
#   '514',
#   '4.57',
#   '1820',
#   '109074',
#   '39',
#   'MARCH 03 2021'],
#  ["I don't want to be the Hive Queen",
#   'Action Adventure Fantasy Gender Bender Magic Non-Human lead Portal Fantasy Isekai Reincarnation Ruling Class Strategy ',
#   '3229',
#   '4.43',
#   '920',
#   '1108638',
#   '87',
#   'MARCH 22 2021'],
#  ['Bottom Rung (Dungeon Runner, book 1)',
#   'Action Adventure Drama Fantasy Dungeon GameLit Magic Male Lead ',
#   '1524',
#   '4.5',
#   '464',
#   '161821',
#   '42',
#   'MARCH 27 2021'],
#  ['Unparalleled',
#   'Action Adventure Comedy Fantasy Romance Portal Fantasy Isekai Strong Lead ',
#   '5662',
#   '4.42',
#   '1807',
#   '2706096',
#   '61',
#   'MARCH 01 2021'],
#  ['This Isekai Adventure Is All Wrong',
#   'Fantasy High Fantasy Magic Male Lead Portal Fantasy Isekai Slice of Life ',
#   '1317',
#   '4.52',
#   '148',
#   '106244',
#   '35',
#   'MARCH 29 2021'],
#  ['REND',
#   'Action Psychological Sci-fi Tragedy Anti-Hero Lead Female Lead Low Fantasy Secret Identity Strategy Strong Lead Super Heroes Supernatural Urban Fantasy ',
#   '1893',
#   '4.44',
#   '824',
#   '316462',
#   '75',
#   'MARCH 28 2021'],
#  ['Black Space',
#   'Adventure Fantasy Sci-fi GameLit LitRPG Male Lead Slice of Life Soft Sci-fi Space Opera Virtual Reality ',
#   '970',
#   '4.53',
#   '460',
#   '197016',
#   '74',
#   'MARCH 29 2021'],
#  ['Forgotten',
#   'Adventure Fantasy Mystery Psychological Female Lead GameLit High Fantasy LitRPG Magic Mythos Non-Human lead Reincarnation Slice of Life Strong Lead ',
#   '2532',
#   '4.41',
#   '1442',
#   '1044768',
#   '154',
#   'MARCH 26 2021'],
#  ['DCO- Dungeon Core Online',
#   'Adventure Comedy Fantasy Sci-fi Dungeon GameLit LitRPG Magic Male Lead Portal Fantasy Isekai Reader interactive School Life Secret Identity Strategy Virtual Reality ',
#   '3232',
#   '4.4',
#   '1828',
#   '3252561',
#   '339',
#   'MARCH 19 2021'],
#  ['Realm of Monsters',
#   'Action Adventure Fantasy Psychological Anti-Hero Lead Dystopia Grimdark High Fantasy Magic Male Lead Non-Human lead Progression School Life ',
#   '2707',
#   '4.42',
#   '804',
#   '552805',
#   '97',
#   'MARCH 29 2021'],
#  ['The Oscillation',
#   'Action Drama Psychological Dungeon Female Lead GameLit Low Fantasy Magic Martial Arts Multiple Lead Characters Mythos Non-Human lead Portal Fantasy Isekai Slice of Life Strong Lead Super Heroes Supernatural Urban Fantasy ',
#   '1599',
#   '4.45',
#   '1928',
#   '651120',
#   '122',
#   'MARCH 29 2021'],
#  ['Druidic Cultivation',
#   'Action Adventure Fantasy Attractive MC Gender Bender Male Lead Martial Arts Portal Fantasy Isekai Progression Reincarnation Slice of Life Strong Lead Supernatural Xianxia ',
#   '2265',
#   '4.44',
#   '484',
#   '378622',
#   '61',
#   'MARCH 29 2021'],
#  ['A fine octet of legs',
#   'Action Adventure Fantasy Female Lead High Fantasy Magic Portal Fantasy Isekai ',
#   '1186',
#   '4.51',
#   '247',
#   '93458',
#   '32',
#   'MARCH 28 2021'],
#  ['System Change',
#   'Action Adventure Comedy Fantasy GameLit LitRPG Magic Portal Fantasy Isekai Post Apocalyptic ',
#   '3589',
#   '4.4',
#   '420',
#   '515104',
#   '62',
#   'MARCH 25 2021'],
#  ['Skybound',
#   'Action Adventure Fantasy Sci-fi Female Lead GameLit High Fantasy LitRPG Low Fantasy Magic Multiple Lead Characters Portal Fantasy Isekai Strong Lead War and Military ',
#   '3615',
#   '4.44',
#   '327',
#   '316385',
#   '23',
#   'MARCH 11 2021'],
#  ['The Last Science',
#   'Contemporary Drama Fantasy Sci-fi Female Lead Low Fantasy Magic Male Lead Multiple Lead Characters Secret Identity Supernatural Urban Fantasy ',
#   '1049',
#   '4.51',
#   '3421',
#   '409440',
#   '118',
#   'MARCH 11 2021'],
#  ['Last Flight of the Raven',
#   'Action Adventure Fantasy High Fantasy LitRPG Male Lead Reincarnation Strategy Strong Lead ',
#   '929',
#   '4.49',
#   '1050',
#   '240336',
#   '122',
#   'MARCH 23 2021'],
#  ['The Morgulon',
#   'Adventure Drama Fantasy Historical High Fantasy Magic Male Lead Multiple Lead Characters Non-Human lead Ruling Class Steampunk Supernatural ',
#   '497',
#   '4.53',
#   '1096',
#   '146262',
#   '105',
#   'MARCH 29 2021'],
#  ['The Legend of Randidly Ghosthound',
#   'Action Fantasy LitRPG ',
#   '12845',
#   '4.33',
#   '10605',
#   '53391577',
#   '1529',
#   'MARCH 14 2021'],
#  ['The Caring Dungeon',
#   'Action Adventure Fantasy Dungeon High Fantasy Magic Male Lead Multiple Lead Characters Non-Human lead Slice of Life Strong Lead ',
#   '1961',
#   '4.42',
#   '486',
#   '640477',
#   '76',
#   'MARCH 29 2021'],
#  ['Leaves of Terranthir',
#   'Action Adventure Fantasy GameLit LitRPG Magic Male Lead Portal Fantasy Isekai Slice of Life ',
#   '1856',
#   '4.43',
#   '330',
#   '175365',
#   '29',
#   'FEBRUARY 25 2021'],
#  ['Embrace the Blade',
#   'Action Adventure Comedy Fantasy Dungeon GameLit High Fantasy LitRPG Magic Male Lead Multiple Lead Characters Non-Human lead Portal Fantasy Isekai Progression Reincarnation Secret Identity Strategy Strong Lead ',
#   '641',
#   '4.57',
#   '519',
#   '62697',
#   '28',
#   'MARCH 23 2021'],
#  ["A Snake's Life",
#   'Action Adventure Fantasy Sci-fi Anti-Hero Lead LitRPG Male Lead Non-Human lead Reincarnation Strong Lead ',
#   '3235',
#   '4.38',
#   '92',
#   '297318',
#   '22',
#   'MARCH 07 2021'],
#  ["Doing God's Work",
#   'Adventure Contemporary Fantasy Psychological Anti-Hero Lead Magic Mythos Strategy Supernatural Urban Fantasy ',
#   '991',
#   '4.8',
#   '804',
#   '299135',
#   '88',
#   'MARCH 21 2021'],
#  ['Even a Hero Needs a Vacation Every Now and Then',
#   'Action Comedy Fantasy Anti-Hero Lead High Fantasy Magic Male Lead Mythos Secret Identity Slice of Life Strong Lead ',
#   '1107',
#   '4.45',
#   '70',
#   '58643',
#   '12',
#   'MARCH 05 2021'],
#  ['Heart of Cultivation',
#   'Action Adventure Fantasy Male Lead Martial Arts Supernatural Xianxia ',
#   '2174',
#   '4.4',
#   '205',
#   '133357',
#   '33',
#   'MARCH 24 2021'],
#  ['Onward To Providence',
#   'Comedy Drama Sci-fi Female Lead High Fantasy Multiple Lead Characters Non-Human lead Slice of Life Space Opera Virtual Reality ',
#   '187',
#   '4.71',
#   '1353',
#   '155048',
#   '249',
#   'MARCH 22 2021'],
#  ['Again from Scratch',
#   'Adventure Fantasy GameLit LitRPG Magic Male Lead Portal Fantasy Isekai Reincarnation Slice of Life ',
#   '2059',
#   '4.42',
#   '686',
#   '290919',
#   '58',
#   'MARCH 26 2021'],
#  ['ATL: Stories from the Retrofuture',
#   'Action Comedy Mystery Sci-fi Artificial Intelligence Cyberpunk Martial Arts Slice of Life Strong Lead Super Heroes Technologically Engineered ',
#   '140',
#   '4.77',
#   '1109',
#   '125150',
#   '226',
#   'MARCH 15 2021'],
#  ['They Called Me MAD',
#   'Action Comedy Fantasy Sci-fi Anti-Hero Lead GameLit LitRPG Low Fantasy Male Lead Post Apocalyptic Super Heroes ',
#   '2919',
#   '4.38',
#   '425',
#   '313573',
#   '75',
#   'MARCH 26 2021'],
#  ['Ursus the Unbearable',
#   'Action Adventure Comedy Fantasy LitRPG Magic Non-Human lead Strong Lead Supernatural ',
#   '1198',
#   '4.5',
#   '111',
#   '40204',
#   '12',
#   'MARCH 29 2021'],
#  ['The Last Science [SE]',
#   'Contemporary Drama Fantasy Sci-fi Female Lead Low Fantasy Magic Male Lead Multiple Lead Characters Secret Identity Urban Fantasy ',
#   '417',
#   '4.49',
#   '3386',
#   '406499',
#   '415',
#   'MARCH 18 2021'],
#  ['This Young Master is not Cannon Fodder',
#   'Action Adventure Comedy Fantasy Anti-Hero Lead High Fantasy Magic Male Lead Martial Arts Mythos Portal Fantasy Isekai Reincarnation Strong Lead Supernatural Xianxia ',
#   '2776',
#   '4.39',
#   '1175',
#   '1071873',
#   '136',
#   'MARCH 29 2021'],
#  ['Displaced',
#   'Action Adventure Fantasy High Fantasy Multiple Lead Characters Portal Fantasy Isekai Strong Lead ',
#   '929',
#   '4.4',
#   '2618',
#   '426548',
#   '110',
#   'MARCH 07 2021'],
#  ['Evil Overlord: So Much Dominating',
#   'Comedy Fantasy Satire Anti-Hero Lead Magic Villainous Lead ',
#   '300',
#   '4.88',
#   '31',
#   '5013',
#   '5',
#   'MARCH 27 2021'],
#  ['Returning to No Applause, Only More of the Same',
#   'Drama Fantasy Psychological Anti-Hero Lead GameLit High Fantasy LitRPG Low Fantasy Magic Male Lead Multiple Lead Characters Portal Fantasy Isekai Secret Identity Slice of Life Strong Lead Supernatural Urban Fantasy ',
#   '3570',
#   '4.34',
#   '340',
#   '651243',
#   '65',
#   'MARCH 28 2021'],
#  ['Dark Skies',
#   'Action Drama Fantasy Tragedy Female Lead High Fantasy Magic Non-Human lead Secret Identity Slice of Life Strong Lead War and Military ',
#   '907',
#   '4.46',
#   '2893',
#   '333771',
#   '168',
#   'MARCH 29 2021'],
#  ['The True Endgame',
#   'Adventure Comedy Fantasy Romance GameLit Harem Magic Male Lead Slice of Life Virtual Reality ',
#   '2437',
#   '4.37',
#   '3465',
#   '2618677',
#   '404',
#   'MARCH 21 2021'],
#  ['Dragon Knight Prophecy',
#   'Adventure Drama Fantasy Romance Harem High Fantasy Male Lead Multiple Lead Characters Non-Human lead Supernatural ',
#   '578',
#   '4.54',
#   '3803',
#   '210447',
#   '164',
#   'MARCH 26 2021'],
#  ['Dragon Heart. Land of War. LitRPG Wuxia Saga. Book 10',
#   'Action Adventure Fantasy Sci-fi GameLit Martial Arts Reincarnation Virtual Reality War and Military Wuxia Xianxia ',
#   '1570',
#   '4.36',
#   '49',
#   '26279',
#   '14',
#   'MARCH 29 2021'],
#  ['Pokemon Animus',
#   'Action Adventure Comedy Sci-fi Anti-Hero Lead Attractive MC GameLit Low Fantasy Magic Male Lead Martial Arts Multiple Lead Characters Portal Fantasy Isekai Progression Reader interactive Slice of Life Soft Sci-fi Sports Strategy ',
#   '564',
#   '4.56',
#   '324',
#   '145908',
#   '43',
#   'MARCH 28 2021'],
#  ['Perspective is Ki (Saiyan, Young Justice, OC)',
#   'Adventure Drama Fantasy Anti-Hero Lead Male Lead Portal Fantasy Isekai Strong Lead Super Heroes Urban Fantasy ',
#   '908',
#   '4.46',
#   '308',
#   '88865',
#   '28',
#   'MARCH 25 2021'],
#  ['Lazy Dragon Queen: Gaming in an Illogical World',
#   'Action Comedy Fantasy Romance GameLit Harem High Fantasy LitRPG Magic Male Lead Portal Fantasy Isekai Slice of Life ',
#   '943',
#   '4.45',
#   '809',
#   '144145',
#   '78',
#   'MARCH 19 2021'],
#  ['Lament of the Slave',
#   'Action Adventure Fantasy Tragedy Female Lead High Fantasy LitRPG Magic Portal Fantasy Isekai Slice of Life ',
#   '744',
#   '4.49',
#   '453',
#   '75564',
#   '39',
#   'MARCH 27 2021'],
#  ['THE SPACE LEGACY',
#   'Action Contemporary Sci-fi Male Lead Space Opera Strong Lead ',
#   '1216',
#   '4.38',
#   '895',
#   '260686',
#   '99',
#   'MARCH 24 2021'],
#  ['Ultra A.I.',
#   'Comedy Mystery Psychological Sci-fi Cyberpunk GameLit Secret Identity Strategy Virtual Reality ',
#   '304',
#   '4.55',
#   '196',
#   '39866',
#   '41',
#   'MARCH 28 2021'],
#  ['The Legion of Nothing',
#   'Action Adventure Fantasy Sci-fi Magic Martial Arts School Life Secret Identity Super Heroes Supernatural ',
#   '553',
#   '4.53',
#   '4138',
#   '3178813',
#   '1192',
#   'MARCH 29 2021'],
#  ['Parasite King',
#   'Fantasy Horror Sci-fi Tragedy Anti-Hero Lead GameLit Grimdark LitRPG Magic Male Lead Martial Arts Mythos Post Apocalyptic Strong Lead Supernatural Urban Fantasy ',
#   '1960',
#   '4.37',
#   '297',
#   '265738',
#   '38',
#   'MARCH 03 2021'],
#  ['Magic-Farming',
#   'Adventure Comedy Fantasy Magic ',
#   '1385',
#   '4.48',
#   '81',
#   '34690',
#   '9',
#   'MARCH 17 2021'],
#  ['Shovels In Spades',
#   'Action Fantasy Romance Tragedy LitRPG Low Fantasy Magic Male Lead Non-Human lead Post Apocalyptic Ruling Class Strong Lead Supernatural ',
#   '4380',
#   '4.31',
#   '2484',
#   '6970103',
#   '362',
#   'MARCH 27 2021'],
#  ['Emperor of Blue Flower Mountain',
#   'Comedy Drama Fantasy Romance Female Lead High Fantasy Slice of Life Supernatural Wuxia ',
#   '263',
#   '4.66',
#   '1284',
#   '209316',
#   '146',
#   'FEBRUARY 23 2021'],
#  ["Valkyrie's Shadow",
#   'Action Adventure Drama Fantasy Anti-Hero Lead Female Lead First Contact GameLit High Fantasy Magic Male Lead Martial Arts Multiple Lead Characters Non-Human lead Portal Fantasy Isekai Progression Ruling Class Slice of Life Strategy ',
#   '119',
#   '4.82',
#   '1455',
#   '57121',
#   '139',
#   'MARCH 29 2021'],
#  ['Fireteam Delta',
#   'Action Contemporary Drama Fantasy Anti-Hero Lead Grimdark Low Fantasy Male Lead Multiple Lead Characters Portal Fantasy Isekai Supernatural ',
#   '359',
#   '4.54',
#   '0',
#   '109',
#   '1',
#   'MARCH 28 2021'],
#  ['Mycology',
#   'Adventure Comedy Fantasy Sci-fi GameLit LitRPG Magic Male Lead Multiple Lead Characters Non-Human lead Slice of Life Strategy Virtual Reality ',
#   '819',
#   '4.46',
#   '896',
#   '291539',
#   '103',
#   'MARCH 25 2021'],
#  ['Thief of Time',
#   'Comedy Fantasy Mystery Psychological Female Lead GameLit Grimdark High Fantasy Magic Male Lead Martial Arts Multiple Lead Characters Mythos Progression Secret Identity Slice of Life Strategy Strong Lead ',
#   '533',
#   '4.55',
#   '567',
#   '123252',
#   '98',
#   'MARCH 26 2021'],
#  ['Planet-Eater Reincarnation (in Star Wars)',
#   'Action Adventure Drama Sci-fi GameLit High Fantasy LitRPG Male Lead Non-Human lead Portal Fantasy Isekai Progression Reincarnation Soft Sci-fi Strong Lead ',
#   '919',
#   '4.49',
#   '119',
#   '73672',
#   '27',
#   'MARCH 28 2021'],
#  ['A Fractured Song',
#   'Adventure Drama Fantasy Romance Female Lead Magic Portal Fantasy Isekai ',
#   '494',
#   '4.5',
#   '1053',
#   '151959',
#   '107',
#   'MARCH 25 2021'],
#  ['Auntie toasts the VRMMORPG',
#   'Comedy Sci-fi Female Lead GameLit LitRPG Magic Martial Arts Reader interactive Slice of Life Strong Lead Virtual Reality ',
#   '964',
#   '4.4',
#   '1505',
#   '579610',
#   '178',
#   'MARCH 17 2021'],
#  ['Atros Imperium',
#   'Action Adventure Fantasy Romance Harem Magic Supernatural ',
#   '3865',
#   '4.32',
#   '6873',
#   '3873386',
#   '255',
#   'MARCH 18 2021'],
#  ['Aeonica',
#   'Action Adventure Drama Fantasy Female Lead High Fantasy Magic Male Lead Martial Arts Multiple Lead Characters Mythos Progression School Life Supernatural War and Military ',
#   '766',
#   '4.44',
#   '1521',
#   '607967',
#   '188',
#   'MARCH 26 2021'],
#  ['Wildling',
#   'Action Fantasy Sci-fi Artificial Intelligence LitRPG Loop Magic Male Lead Technologically Engineered ',
#   '318',
#   '4.64',
#   '353',
#   '40217',
#   '53',
#   'MARCH 29 2021'],
#  ['OASIS CORE',
#   'Action Adventure Fantasy Mystery Dungeon Dystopia Grimdark High Fantasy LitRPG Magic Post Apocalyptic Steampunk Strategy ',
#   '1953',
#   '4.4',
#   '399',
#   '361126',
#   '76',
#   'FEBRUARY 22 2021'],
#  ["A Tail's Misfortune",
#   'Action Drama Fantasy Psychological Female Lead Low Fantasy Magic Mythos Non-Human lead School Life Strong Lead Supernatural ',
#   '1034',
#   '4.41',
#   '1921',
#   '626562',
#   '144',
#   'MARCH 19 2021'],
#  ['Memories of the Fall',
#   'Action Adventure Fantasy Female Lead High Fantasy Magic Martial Arts Multiple Lead Characters Mythos Progression Supernatural Wuxia Xianxia ',
#   '576',
#   '4.5',
#   '4934',
#   '147109',
#   '95',
#   'MARCH 28 2021'],
#  ['The Runesmith',
#   'Action Adventure Fantasy Dungeon GameLit High Fantasy LitRPG Magic Male Lead Mythos Portal Fantasy Isekai Ruling Class Slice of Life ',
#   '5734',
#   '4.29',
#   '991',
#   '1464212',
#   '93',
#   'MARCH 26 2021'],
#  ['Undying Empire',
#   'Action Adventure Fantasy Psychological Anti-Hero Lead Female Lead GameLit Grimdark Multiple Lead Characters Non-Human lead Portal Fantasy Isekai Slice of Life Strategy Strong Lead Supernatural War and Military ',
#   '1161',
#   '4.39',
#   '1361',
#   '257398',
#   '71',
#   'MARCH 26 2021'],
#  ["What's A Koopa To Do? (My Hero Academia/Bowser Self-Insert Story)",
#   'Action Comedy Sci-fi School Life ',
#   '171',
#   '4.78',
#   '117',
#   '4838',
#   '7',
#   'MARCH 27 2021'],
#  ['Melas',
#   'Action Adventure Fantasy Female Lead Grimdark Magic Multiple Lead Characters Portal Fantasy Isekai Progression Reincarnation Secret Identity Strong Lead ',
#   '2369',
#   '4.32',
#   '888',
#   '335141',
#   '67',
#   'MARCH 28 2021'],
#  ['Saga of the Soul Dungeon',
#   'Action Adventure Fantasy Psychological Dungeon GameLit LitRPG Magic Male Lead Multiple Lead Characters Non-Human lead Progression Reincarnation Strong Lead ',
#   '657',
#   '4.6',
#   '95',
#   '8992',
#   '9',
#   'MARCH 27 2021'],
#  ['A Jaded Life',
#   'Action Adventure Fantasy Romance Anti-Hero Lead Female Lead LitRPG Virtual Reality ',
#   '2302',
#   '4.32',
#   '2608',
#   '2543228',
#   '440',
#   'MARCH 29 2021'],
#  ['The Infinite Labyrinth',
#   'Adventure Fantasy Historical Dungeon High Fantasy LitRPG Male Lead Multiple Lead Characters Steampunk ',
#   '809',
#   '4.45',
#   '1206',
#   '429072',
#   '162',
#   'MARCH 14 2021'],
#  ['Heather the Necromancer',
#   'Adventure Comedy Fantasy Female Lead GameLit High Fantasy LitRPG Magic Portal Fantasy Isekai Slice of Life Supernatural ',
#   '1750',
#   '4.34',
#   '1638',
#   '612629',
#   '112',
#   'MARCH 23 2021'],
#  ['Wreath of Lilies, Cauldron of Poison',
#   'Action Adventure Fantasy Romance Anti-Hero Lead Female Lead Gender Bender Harem High Fantasy Magic Martial Arts Reincarnation Strong Lead Villainous Lead Xianxia ',
#   '1428',
#   '4.36',
#   '1075',
#   '786666',
#   '137',
#   'MARCH 21 2021'],
#  ['Nova Terra: Titan',
#   'Action Adventure Fantasy Sci-fi GameLit LitRPG Magic Male Lead Martial Arts Strong Lead ',
#   '2079',
#   '4.33',
#   '1928',
#   '1235713',
#   '218',
#   'MARCH 15 2021'],
#  ['The Eighth Warden',
#   'Action Adventure Fantasy High Fantasy Magic ',
#   '486',
#   '4.52',
#   '1439',
#   '219927',
#   '94',
#   'MARCH 23 2021'],
#  ['Pieces of Sonder',
#   'Action Adventure Fantasy Dungeon Female Lead GameLit LitRPG Magic ',
#   '672',
#   '4.48',
#   '313',
#   '129435',
#   '74',
#   'MARCH 26 2021'],
#  ['Adventures of the Goldthirst Company',
#   'Action Adventure Comedy Fantasy Female Lead High Fantasy Magic Multiple Lead Characters ',
#   '327',
#   '4.57',
#   '2086',
#   '236635',
#   '225',
#   'MARCH 24 2021'],
#  ['Savage Divinity',
#   'Action Adventure Fantasy Harem Martial Arts Slice of Life ',
#   '8464',
#   '4.25',
#   '10490',
#   '23500905',
#   '695',
#   'MARCH 28 2021'],
#  ['Silver Fox and the Western Hero',
#   'Action Adventure Fantasy GameLit High Fantasy LitRPG Male Lead Portal Fantasy Isekai Reincarnation Wuxia Xianxia ',
#   '1116',
#   '4.36',
#   '646',
#   '189414',
#   '39',
#   'MARCH 22 2021'],
#  ['Dungeon Annihilation: A Dungeon Robotics Alternative',
#   'Action Adventure Fantasy Sci-fi Anti-Hero Lead Dungeon Female Lead Grimdark Harem High Fantasy Magic Male Lead Multiple Lead Characters Reincarnation Strategy Strong Lead Villainous Lead War and Military ',
#   '613',
#   '4.47',
#   '578',
#   '152377',
#   '73',
#   'MARCH 26 2021'],
#  ['Aced: A Slice of Life Tennis LitRPG',
#   'Action Adventure Comedy Drama GameLit LitRPG Low Fantasy Male Lead Portal Fantasy Isekai Progression Reincarnation School Life Slice of Life Sports Strategy ',
#   '476',
#   '4.54',
#   '172',
#   '41674',
#   '29',
#   'MARCH 08 2021'],
#  ['Summoned! To an RPG world (LitRPG)',
#   'Fantasy GameLit LitRPG Portal Fantasy Isekai ',
#   '1049',
#   '4.39',
#   '398',
#   '99783',
#   '41',
#   'MARCH 28 2021'],
#  ['Confessions of the Magpie Wizard',
#   'Comedy Drama Fantasy Romance Anti-Hero Lead Low Fantasy Magic Male Lead Non-Human lead School Life Secret Identity Supernatural Urban Fantasy ',
#   '725',
#   '4.37',
#   '480',
#   '84686',
#   '63',
#   'FEBRUARY 28 2021'],
#  ['Into the Black',
#   'Action Adventure Sci-fi Gender Bender Harem LitRPG Non-Human lead Strong Lead Virtual Reality ',
#   '3206',
#   '4.3',
#   '2422',
#   '4213398',
#   '340',
#   'MARCH 23 2021'],
#  ['Painting the Mists',
#   'Action Adventure Fantasy High Fantasy Magic Male Lead Martial Arts Multiple Lead Characters Progression Reincarnation Supernatural Wuxia Xianxia ',
#   '1283',
#   '4.3',
#   '31',
#   '85673',
#   '4',
#   'MARCH 21 2021'],
#  ['Girl with the Golden Eyes',
#   'Action Adventure Fantasy Anti-Hero Lead Female Lead Grimdark High Fantasy Magic Multiple Lead Characters Non-Human lead Portal Fantasy Isekai Strong Lead ',
#   '620',
#   '4.45',
#   '85',
#   '4593',
#   '6',
#   'MARCH 08 2021'],
#  ['The Adventures of Einarr Stigandersen',
#   'Action Adventure Fantasy High Fantasy Magic Male Lead Mythos Strong Lead ',
#   '209',
#   '4.65',
#   '1367',
#   '377313',
#   '372',
#   'FEBRUARY 25 2021'],
#  ['The Last Man Standing',
#   'Action Mystery Romance Sci-fi Anti-Hero Lead Multiple Lead Characters Strategy Supernatural War and Military ',
#   '131',
#   '4.8',
#   '1109',
#   '29050',
#   '60',
#   'MARCH 27 2021'],
#  ['Requiem',
#   'Action Adventure Fantasy Horror Anti-Hero Lead GameLit Grimdark High Fantasy Magic Male Lead Martial Arts Mythos Post Apocalyptic Strategy Strong Lead Supernatural Urban Fantasy ',
#   '316',
#   '4.37',
#   '770',
#   '40584',
#   '69',
#   'MARCH 26 2021'],
#  ['The Patchwork Realms: Arrival',
#   'Action Adventure Fantasy GameLit High Fantasy LitRPG Magic Male Lead Non-Human lead Portal Fantasy Isekai Strong Lead ',
#   '230',
#   '4.65',
#   '399',
#   '32070',
#   '24',
#   'MARCH 28 2021'],
#  ['In Umbra Hasta',
#   'Action Adventure Fantasy GameLit LitRPG Low Fantasy Magic Male Lead Martial Arts Post Apocalyptic Strategy Strong Lead ',
#   '2402',
#   '4.29',
#   '817',
#   '409664',
#   '72',
#   'MARCH 07 2021'],
#  ['Dungeon 42- Old',
#   'Adventure Comedy Fantasy Horror Dungeon Female Lead GameLit Magic Non-Human lead Slice of Life ',
#   '1193',
#   '4.34',
#   '609',
#   '271959',
#   '65',
#   'MARCH 12 2021'],
#  ['Leveling up the World',
#   'Action Adventure GameLit Male Lead Portal Fantasy Isekai ',
#   '2207',
#   '4.31',
#   '353',
#   '421753',
#   '87',
#   'MARCH 29 2021'],
#  ['Station 64: Azaria The Doll Dungeon',
#   'Action Adventure Fantasy Romance Dungeon Female Lead GameLit Grimdark LitRPG Magic Male Lead Multiple Lead Characters Non-Human lead Reincarnation Strategy Strong Lead ',
#   '1223',
#   '4.37',
#   '268',
#   '142559',
#   '38',
#   'MARCH 27 2021'],
#  ['Shade and Flow (A Dystopian LitRPG story)',
# ...
#   '9',
#   '5',
#   '114',
#   '419',
#   '5',
#   'FEBRUARY 27 2021'],
#  ['The White Room',
#   'Comedy Horror Psychological Satire Non-Human lead Post Apocalyptic Slice of Life ',
#   '0',
#   '5',
#   '9',
#   '97',
#   '3',
#   'MARCH 25 2021'],
#  ['Wan Lin (Cultivation Novel)',
#   'Action Adventure Anti-Hero Lead Grimdark Male Lead Martial Arts Progression Xianxia ',
#   '19',
#   '4.2',
#   '31',
#   '533',
#   '5',
#   'MARCH 02 2021'],
#  ['Crew of the Helianthus',
#   'Sci-fi Multiple Lead Characters Non-Human lead ',
#   '31',
#   '4.88',
#   '299',
#   '6990',
#   '57',
#   'MARCH 29 2021'],
#  ['When Life Stands Still (bxb)',
#   'Action Fantasy Romance Sci-fi Low Fantasy Male Lead Martial Arts Multiple Lead Characters Post Apocalyptic Reincarnation Secret Identity Strategy Strong Lead Supernatural Urban Fantasy War and Military ',
#   '10',
#   '4.83',
#   '607',
#   '2207',
#   '37',
#   'MARCH 19 2021'],
#  ['The Revenge Story Of The Holder Of 【The Archives Of Knowledge】 In Another World',
#   'Action Adventure Fantasy Harem High Fantasy Magic Male Lead Portal Fantasy Isekai Strong Lead ',
#   '155',
#   '2.94',
#   '397',
#   '56396',
#   '71',
#   'MARCH 24 2021'],
#  ['Retiring as an Incompetent Queen',
#   'Action Adventure Fantasy Anti-Hero Lead Female Lead GameLit High Fantasy Magic Multiple Lead Characters Portal Fantasy Isekai Progression Reincarnation Ruling Class Secret Identity Strategy Strong Lead Villainous Lead ',
#   '43',
#   '3.75',
#   '260',
#   '6319',
#   '29',
#   'MARCH 02 2021'],
#  ['The Milostiv',
#   'Action Adventure Fantasy Tragedy Anti-Hero Lead Low Fantasy Magic Male Lead Multiple Lead Characters Mythos Strategy War and Military ',
#   '30',
#   '3.82',
#   '518',
#   '10574',
#   '69',
#   'MARCH 21 2021'],
#  ['Divinity',
#   'Adventure Fantasy High Fantasy Male Lead Multiple Lead Characters ',
#   '28',
#   '3.93',
#   '654',
#   '12765',
#   '53',
#   'MARCH 28 2021'],
#  ['My Quiet Life',
#   'Drama Fantasy Historical Romance Female Lead High Fantasy Ruling Class ',
#   '10',
#   '4.75',
#   '60',
#   '732',
#   '11',
#   'MARCH 25 2021'],
#  ['Pasted Gunner',
#   'Action Adventure Comedy Fantasy LitRPG Magic Portal Fantasy Isekai War and Military ',
#   '26',
#   '3.9',
#   '114',
#   '6868',
#   '25',
#   'MARCH 18 2021'],
#  ['I.D. Tech',
#   'Adventure Drama Psychological Sci-fi Male Lead Technologically Engineered ',
#   '13',
#   '4.17',
#   '97',
#   '1266',
#   '27',
#   'MARCH 17 2021'],
#  ['The Xeno King',
#   'Action Adventure Fantasy Romance Anti-Hero Lead Harem High Fantasy LitRPG Magic Male Lead Portal Fantasy Isekai ',
#   '35',
#   '4.42',
#   '140',
#   '1668',
#   '9',
#   'MARCH 21 2021'],
#  ['Hello Troublemaker',
#   'Action Comedy Drama Romance Anti-Hero Lead Attractive MC Female Lead First Contact Male Lead Martial Arts Multiple Lead Characters Non-Human lead Progression Ruling Class School Life Secret Identity Sports Strong Lead Wuxia ',
#   '5',
#   '4.8',
#   '2',
#   '13',
#   '1',
#   'MARCH 13 2021'],
#  ['Elements of Reality',
#   'Action Adventure Fantasy Romance Low Fantasy Magic Male Lead Martial Arts Multiple Lead Characters School Life Strategy Strong Lead Supernatural ',
#   '82',
#   '3.5',
#   '732',
#   '23544',
#   '44',
#   'MARCH 26 2021'],
#  ['Soul Forged, Book 01',
#   'Action Adventure Contemporary Fantasy Female Lead GameLit High Fantasy LitRPG Magic Male Lead Multiple Lead Characters Portal Fantasy Isekai Strong Lead ',
#   '35',
#   '5',
#   '381',
#   '2242',
#   '33',
#   'MARCH 29 2021'],
#  ['I Reincarnated as A Little Girl?!',
#   'Action Fantasy Mystery Romance Female Lead Gender Bender Multiple Lead Characters Reincarnation ',
#   '235',
#   '2.8',
#   '823',
#   '178254',
#   '212',
#   'MARCH 28 2021'],
#  ['BEYOND THE AVERAGE ISEKAI (A LITRPG)',
#   'Action Adventure Comedy Fantasy Attractive MC Dungeon High Fantasy LitRPG Magic Male Lead Portal Fantasy Isekai Progression Reincarnation Slice of Life Strong Lead ',
#   '36',
#   '4.14',
#   '134',
#   '1691',
#   '10',
#   'MARCH 27 2021'],
#  ['Programming Wizards!',
#   'Sci-fi School Life ',
#   '16',
#   '4.75',
#   '40',
#   '3417',
#   '10',
#   'MARCH 28 2021'],
#  ["Battlemaster's Gambit A LITRPG Monstergirl Harem Adventure",
#   'Adventure Fantasy GameLit Harem High Fantasy LitRPG Male Lead Supernatural ',
#   '32',
#   '3.89',
#   '82',
#   '1248',
#   '5',
#   'MARCH 24 2021'],
#  ['Climbing out of the Ruin',
#   'Action Adventure Fantasy Mystery Anti-Hero Lead Dungeon Magic Male Lead Martial Arts Reincarnation Secret Identity ',
#   '32',
#   '4.33',
#   '259',
#   '13388',
#   '43',
#   'MARCH 05 2021'],
#  ['The Smith and the Knight',
#   'Action Fantasy Romance Sci-fi Anti-Hero Lead Female Lead Grimdark Magic Multiple Lead Characters Supernatural ',
#   '56',
#   '4.5',
#   '360',
#   '22974',
#   '37',
#   'FEBRUARY 23 2021'],
#  ['Athanor',
#   'Action Adventure Drama Fantasy Magic ',
#   '47',
#   '4.75',
#   '427',
#   '12021',
#   '59',
#   'MARCH 27 2021'],
#  ['Winter',
#   'Action Adventure Fantasy Attractive MC Female Lead GameLit Magic Slice of Life Strong Lead ',
#   '14',
#   '4.75',
#   '8',
#   '218',
#   '2',
#   'MARCH 02 2021'],
#  ['A Festival of Fools',
#   'Action Adventure Contemporary Mystery Anti-Hero Lead Multiple Lead Characters School Life Sports Strategy ',
#   '8',
#   '4.75',
#   '309',
#   '1474',
#   '24',
#   'MARCH 26 2021'],
#  ['The Academy: Year One',
#   'Action Adventure Sci-fi Male Lead School Life Soft Sci-fi ',
#   '9',
#   '4.67',
#   '73',
#   '393',
#   '8',
#   'MARCH 06 2021'],
#  ['Chaos Of The New Era',
#   'Action Adventure Fantasy Tragedy Anti-Hero Lead High Fantasy Magic Male Lead Martial Arts Mythos Progression ',
#   '37',
#   '3.68',
#   '462',
#   '11986',
#   '63',
#   'MARCH 28 2021'],
#  ['Arawulf, the First Daughter',
#   'Drama Fantasy Romance Female Lead Magic Multiple Lead Characters Mythos Ruling Class Strong Lead ',
#   '42',
#   '4.25',
#   '294',
#   '7592',
#   '51',
#   'FEBRUARY 26 2021'],
#  ['In a World Without Coffee',
#   'Adventure Comedy Fantasy Romance Attractive MC Dystopia Female Lead Low Fantasy Magic Male Lead Multiple Lead Characters Non-Human lead Portal Fantasy Isekai Reincarnation Strong Lead Supernatural ',
#   '26',
#   '4.88',
#   '182',
#   '5330',
#   '36',
#   'MARCH 26 2021'],
#  ['There Are Superheroes In This Story',
#   'Action Psychological Sci-fi Female Lead Progression Super Heroes ',
#   '21',
#   '4.88',
#   '57',
#   '784',
#   '10',
#   'MARCH 27 2021'],
#  ['THE EMPIRE OF ASHES',
#   'Action Fantasy Sci-fi Anti-Hero Lead Artificial Intelligence Cyberpunk Dystopia Female Lead Genetically Engineered Grimdark Hard Sci-fi Low Fantasy Male Lead Multiple Lead Characters Post Apocalyptic Reincarnation Ruling Class Soft Sci-fi Steampunk ',
#   '19',
#   '4.88',
#   '122',
#   '2292',
#   '18',
#   'MARCH 24 2021'],
#  ['The Ruler of Murim wishes for Death.',
#   'Action Adventure Drama Fantasy GameLit High Fantasy LitRPG Magic Martial Arts Portal Fantasy Isekai Progression Reincarnation Strong Lead Super Heroes Wuxia ',
#   '20',
#   '5',
#   '40',
#   '356',
#   '2',
#   'MARCH 18 2021'],
#  ['Cairo',
#   'Action Adventure Fantasy Mystery High Fantasy Magic Male Lead Urban Fantasy ',
#   '10',
#   '5',
#   '102',
#   '493',
#   '9',
#   'MARCH 29 2021'],
#  ['The Bloodlet Sun',
#   'Adventure Sci-fi Female Lead Low Fantasy Male Lead Multiple Lead Characters Non-Human lead Soft Sci-fi Space Opera ',
#   '9',
#   '5',
#   '109',
#   '2114',
#   '30',
#   'MARCH 25 2021'],
#  ["Crossliner's coup d'etat",
#   'Drama Fantasy Magic Male Lead Portal Fantasy Isekai Ruling Class Slice of Life War and Military ',
#   '3',
#   '5',
#   '151',
#   '675',
#   '14',
#   'MARCH 10 2021'],
#  ['I was reborn as postmodernist fiction???',
#   'Adventure Comedy Psychological Satire Harem Magic Male Lead Multiple Lead Characters Non-Human lead Portal Fantasy Isekai Reincarnation School Life Slice of Life Supernatural ',
#   '0',
#   '5',
#   '3',
#   '34',
#   '1',
#   'MARCH 27 2021'],
#  ['Tenshot',
#   'Action Adventure Fantasy Sci-fi Anti-Hero Lead LitRPG Male Lead Post Apocalyptic Progression Soft Sci-fi Supernatural Urban Fantasy ',
#   '24',
#   '3.5',
#   '471',
#   '8477',
#   '50',
#   'MARCH 29 2021'],
#  ['Asleep - A LITRPG story',
#   'Fantasy GameLit LitRPG ',
#   '18',
#   '4.33',
#   '157',
#   '1450',
#   '18',
#   'MARCH 29 2021'],
#  ['Sanctity of Blood',
#   'Action Adventure Fantasy Psychological High Fantasy Low Fantasy Magic Male Lead Martial Arts Reincarnation Secret Identity Strong Lead Xianxia ',
#   '15',
#   '4.33',
#   '84',
#   '3214',
#   '20',
#   'MARCH 16 2021'],
#  ['Hodgepodge',
#   'Adventure Fantasy Sci-fi Short Story Anti-Hero Lead Female Lead High Fantasy Low Fantasy Magic Male Lead Multiple Lead Characters Mythos Reincarnation Steampunk Super Heroes Supernatural Urban Fantasy ',
#   '12',
#   '4.83',
#   '584',
#   '17725',
#   '82',
#   'MARCH 07 2021'],
#  ['Lucine: Nightmares of The Blood Moon Heiress',
#   'Adventure Fantasy Mystery Romance Female Lead Low Fantasy Progression School Life Secret Identity Strong Lead Supernatural ',
#   '5',
#   '4.83',
#   '53',
#   '468',
#   '12',
#   'MARCH 12 2021'],
#  ["Epoch: An NPC's Tale",
#   'Action Adventure Drama Fantasy GameLit High Fantasy LitRPG Magic Male Lead Portal Fantasy Isekai Progression Ruling Class School Life Secret Identity Strategy Time Travel War and Military ',
#   '23',
#   '4.14',
#   '176',
#   '3749',
#   '25',
#   'MARCH 17 2021'],
#  ['Game of Thrones: King Business - Tommen OC/SI',
#   'Action Fantasy Psychological Romance Anti-Hero Lead Magic Male Lead Reincarnation Strategy War and Military ',
#   '27',
#   '4.83',
#   '53',
#   '1258',
#   '13',
#   'MARCH 28 2021'],
#  ['Ogre Tyrant',
#   'Adventure Fantasy Dungeon High Fantasy LitRPG Magic Male Lead Portal Fantasy Isekai ',
#   '15',
#   '4.83',
#   '232',
#   '419',
#   '4',
#   'MARCH 27 2021'],
#  ['General Grievance: How to derail the Star Wars Plot',
#   'Action Adventure Fantasy Sci-fi Anti-Hero Lead Male Lead Portal Fantasy Isekai Progression Reincarnation Secret Identity Soft Sci-fi Space Opera Strategy Strong Lead Supernatural Technologically Engineered ',
#   '15',
#   '4.4',
#   '32',
#   '319',
#   '2',
#   'MARCH 27 2021'],
#  ['Dungeon Crawler Katia',
#   'Action Adventure Fantasy Dungeon GameLit Magic Portal Fantasy Isekai ',
#   '29',
#   '4.75',
#   '595',
#   '5430',
#   '24',
#   'MARCH 27 2021'],
#  ["An Anomaly's Life Inside A Galge is Seriously too harsh for me!",
#   'Adventure Comedy Fantasy Romance Dungeon Female Lead First Contact GameLit Harem LitRPG Low Fantasy Magic Male Lead Martial Arts Multiple Lead Characters Mythos Portal Fantasy Isekai Progression Reincarnation ',
#   '15',
#   '3.71',
#   '216',
#   '3001',
#   '21',
#   'MARCH 28 2021'],
#  ['NEVER JUDGE',
#   'Adventure Contemporary Drama Attractive MC Male Lead Multiple Lead Characters Secret Identity Slice of Life ',
#   '20',
#   '4.14',
#   '155',
#   '3753',
#   '40',
#   'MARCH 05 2021'],
#  ['Life Without Time',
#   'Action Adventure Fantasy Magic Male Lead Progression Strong Lead ',
#   '10',
#   '4.07',
#   '221',
#   '1970',
#   '33',
#   'FEBRUARY 24 2021'],
#  ['Dots',
#   'Action Adventure Romance Sci-fi Anti-Hero Lead Female Lead Harem Low Fantasy Male Lead Multiple Lead Characters Reincarnation Soft Sci-fi Xianxia ',
#   '13',
#   '4.38',
#   '263',
#   '3288',
#   '31',
#   'MARCH 26 2021'],
#  ['I Reincarnated as an Elf in a Broken World.',
#   'Action Drama Fantasy Tragedy Female Lead Gender Bender Magic Reincarnation ',
#   '181',
#   '2.89',
#   '326',
#   '63068',
#   '96',
#   'MARCH 28 2021'],
#  ['The Edge of Vision',
#   'Action Adventure Fantasy Dystopia High Fantasy Male Lead Portal Fantasy Isekai Progression Reincarnation School Life Supernatural ',
#   '5',
#   '4.5',
#   '74',
#   '514',
#   '9',
#   'FEBRUARY 28 2021'],
#  ['Maroon Odyssey: Story of the survivors of a plane crash in a magical world',
#   'Adventure Fantasy GameLit High Fantasy Multiple Lead Characters Portal Fantasy Isekai Progression ',
#   '18',
#   '3.64',
#   '176',
#   '3678',
#   '34',
#   'MARCH 09 2021'],
#  ['Living Armor',
#   'Action Fantasy Romance Dungeon Magic Male Lead Progression Reincarnation ',
#   '30',
#   '4.25',
#   '53',
#   '1737',
#   '11',
#   'MARCH 11 2021'],
#  ['Immortal Stranger',
#   'Action Drama Fantasy Tragedy Anti-Hero Lead High Fantasy Magic Male Lead Martial Arts Multiple Lead Characters Non-Human lead Secret Identity Strategy Strong Lead Supernatural ',
#   '14',
#   '4.62',
#   '108',
#   '4301',
#   '29',
#   'MARCH 12 2021'],
#  ['Ethically Sound Unethical Procedure',
#   'Action Adventure Fantasy Psychological Anti-Hero Lead Female Lead LitRPG Magic Post Apocalyptic Progression Ruling Class ',
#   '37',
#   '4.07',
#   '108',
#   '1898',
#   '14',
#   'MARCH 25 2021'],
#  ['Chronicles of Alex Chase',
#   'Action Adventure Fantasy Psychological Anti-Hero Lead Dystopia High Fantasy Magic Male Lead Portal Fantasy Isekai Soft Sci-fi Urban Fantasy ',
#   '31',
#   '4.5',
#   '133',
#   '2177',
#   '15',
#   'MARCH 21 2021'],
#  ['Beyond Humanity: Lightning Falling and Hook of Rage',
#   'Action Adventure Sci-fi Magic Multiple Lead Characters Space Opera Supernatural ',
#   '56',
#   '3.65',
#   '1023',
#   '21659',
#   '107',
#   'MARCH 29 2021'],
#  ['Deep In The Heart 2019',
#   'Action Drama Fantasy Romance Anti-Hero Lead Female Lead Low Fantasy Magic Multiple Lead Characters Mythos School Life Slice of Life Supernatural ',
#   '10',
#   '3.56',
#   '450',
#   '13416',
#   '48',
#   'MARCH 01 2021'],
#  ['Abyssal Dragon: Awakening',
#   'Action Adventure Fantasy Tragedy Anti-Hero Lead Attractive MC LitRPG Male Lead Non-Human lead Reincarnation Strong Lead Villainous Lead ',
#   '30',
#   '4.75',
#   '25',
#   '931',
#   '6',
#   'FEBRUARY 25 2021'],
#  ['Visions of Dark & Light',
#   'Action Adventure Fantasy Romance Female Lead Grimdark Magic Male Lead Portal Fantasy Isekai Reincarnation Steampunk Strong Lead Urban Fantasy ',
#   '21',
#   '4.75',
#   '349',
#   '3395',
#   '27',
#   'MARCH 20 2021'],
#  ['Mite',
#   'Action Adventure Contemporary Sci-fi Male Lead Multiple Lead Characters Secret Identity Strong Lead Super Heroes ',
#   '19',
#   '4.75',
#   '309',
#   '15699',
#   '73',
#   'MARCH 28 2021'],
#  ['Path of the Ancients',
#   'Adventure Fantasy Romance Sci-fi Female Lead Magic Male Lead Multiple Lead Characters Strong Lead ',
#   '16',
#   '4.75',
#   '485',
#   '1735',
#   '18',
#   'MARCH 02 2021'],
#  ['Love and Anti-Peace',
#   'Action Comedy Fantasy Mystery Dystopia High Fantasy Magic Male Lead Non-Human lead Secret Identity Strategy ',
#   '4',
#   '4.75',
#   '17',
#   '233',
#   '6',
#   'FEBRUARY 28 2021'],
#  ['Summoned as a Ghost in another world',
#   'Action Adventure Fantasy Romance Anti-Hero Lead Dungeon Harem High Fantasy LitRPG Magic Male Lead Martial Arts Portal Fantasy Isekai Reincarnation Supernatural ',
#   '50',
#   '3.7',
#   '43',
#   '3441',
#   '11',
#   'MARCH 26 2021'],
#  ['The Jinni and The Isekai',
#   'Action Adventure Fantasy Romance Dungeon Harem High Fantasy Male Lead Portal Fantasy Isekai Slice of Life Strong Lead ',
#   '45',
#   '3.83',
#   '122',
#   '6341',
#   '43',
#   'MARCH 23 2021'],
#  ['In the Shadow of the Builders',
#   'Contemporary Drama Sci-fi Short Story Artificial Intelligence Female Lead Post Apocalyptic Slice of Life Soft Sci-fi Technologically Engineered ',
#   '8',
#   '5',
#   '44',
#   '155',
#   '5',
#   'MARCH 28 2021'],
#  ['Aberrant Tales',
#   'Adventure Drama Fantasy Psychological Grimdark High Fantasy Magic Multiple Lead Characters Mythos Post Apocalyptic Strategy Supernatural ',
#   '5',
#   '5',
#   '404',
#   '399',
#   '18',
#   'MARCH 28 2021'],
#  ['Thiefdom',
#   'Action Adventure Fantasy Romance High Fantasy Magic Male Lead Portal Fantasy Isekai ',
#   '5',
#   '5',
#   '33',
#   '289',
#   '6',
#   'FEBRUARY 26 2021'],
#  ['Trash',
#   'Drama Psychological Romance Tragedy Female Lead Grimdark Male Lead Multiple Lead Characters ',
#   '3',
#   '5',
#   '60',
#   '310',
#   '10',
#   'MARCH 22 2021'],
#  ['Autumn Winds and Crimson Waters',
#   'Adventure Fantasy Psychological Short Story Female Lead Male Lead Multiple Lead Characters Non-Human lead ',
#   '3',
#   '5',
#   '48',
#   '2097',
#   '19',
#   'FEBRUARY 23 2021'],
#  ['The Returned',
#   'Action Adventure Fantasy Attractive MC LitRPG Magic Male Lead Multiple Lead Characters Portal Fantasy Isekai ',
#   '16',
#   '4.62',
#   '65',
#   '498',
#   '5',
#   'MARCH 02 2021'],
#  ['Potestera- Race for Power',
#   'Action Adventure Fantasy Satire High Fantasy Magic Male Lead Martial Arts Portal Fantasy Isekai Post Apocalyptic Reincarnation Supernatural ',
#   '18',
#   '4.3',
#   '208',
#   '6274',
#   '40',
#   'MARCH 26 2021'],
#  ['Thomas the Brawler',
#   'Adventure Comedy Fantasy LitRPG Magic Male Lead Portal Fantasy Isekai Slice of Life ',
#   '18',
#   '3.93',
#   '205',
#   '2725',
#   '21',
#   'MARCH 16 2021'],
#  ...]

# %%
# Fix problems in other chapters 
failed = []
for o in other:
    info = o.split(';')[0:8]
    info2 = o.split(';')[8:]
    
    try:
        # Add title
        info2.insert(0, info[7].split('2021')[1])

        # add date
        info[7] = info[7].split('2021')[0] + '2021'
        
        # Clean Data 
        info[1] = info[1].replace('|', ' ').replace('/ ', '') # Tags 
        info[2] = info[2].strip(' FOLLOWERS').replace(',', '') # Followers 
        info[4] = info[4].strip(' PAGES').replace(',', '')  # Pages 
        info[5] = info[5].strip(' VIEWS').replace(',', '')  # Views 
        info[6] = info[6].strip(' CHAPTERS').replace(',', '')  # Chapters 
        info[7] = info[7].strip('\n').replace(',', '') # date last updated 
        
        
        info2[1] = info2[1].replace('|', ' ').replace('/ ', '') # Tags 
        info2[2] = info2[2].strip(' FOLLOWERS').replace(',', '') # Followers 
        info2[4] = info2[4].strip(' PAGES').replace(',', '')  # Pages 
        info2[5] = info2[5].strip(' VIEWS').replace(',', '')  # Views 
        info2[6] = info2[6].strip(' CHAPTERS').replace(',', '')  # Chapters 
        info2[7] = info2[7].strip('\n').replace(',', '') # date last updated 
        
        books.append(info)
        books.append(info2)
    except:
        failed.append(o)

print(f'Size of -> books: {len(books)}, failed: {len(failed)}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-b227fead9639> in <module>
#       1 # Fix problems in other chapters
#       2 failed = []
# ----> 3 for o in other:
#       4     info = o.split(';')[0:8]
#       5     info2 = o.split(';')[8:]
#
# NameError: name 'other' is not defined

# %%
for f in failed:
    x = f.split(';')
    info = [None, None, None, None, None, None, None, None]
    
    info[0] = x[0] + x[1]
    info[1] = x[2].replace('|', ' ').replace('/ ', '') # Tags 
    info[2] = x[3].strip(' FOLLOWERS').replace(',', '') # Followers 
    info[3] = x[4]
    info[4] = x[5].strip(' PAGES').replace(',', '')  # Pages 
    info[5] = x[6].strip(' VIEWS').replace(',', '')  # Views 
    info[6] = x[7].strip(' CHAPTERS').replace(',', '')  # Chapters 
    info[7] = x[8].strip('\n').replace(',', '') # date last updated 
    
    books.append(info)

print(f'Size of -> books: {len(books)}, failed: {len(failed)}')
# Out:
# Size of -> books: 2719, failed: 9

# %%
# Fix error with book at index 2501 

'''
for i, b in enumerate(books):
    if len(b) != 8:
        print(i, b)
'''
x = books[2501]
info = [None, None, None, None, None, None, None, None]

info[0] = x[0] + x[1]
info[1] = x[2].replace('|', ' ').replace('/ ', '') # Tags 
info[2] = x[3].strip(' FOLLOWERS').replace(',', '') # Followers 
info[3] = x[4]
info[4] = x[5].strip(' PAGES').replace(',', '')  # Pages 
info[5] = x[6].strip(' VIEWS').replace(',', '')  # Views 
info[6] = x[7].strip(' CHAPTERS').replace(',', '')  # Chapters 
info[7] = x[8].strip('\n').replace(',', '') # date last updated 

books[2501] = info

# %% [markdown]
# # Explore the Data

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import nltk_helper as local_nltk


# %matplotlib inline

plt.style.use('seaborn')

# %%
# Make books into dataframe 
df = pd.DataFrame(data = books[1:], columns = books[0])
df.head()
# Out:
#                          title  \
# 0            Beware Of Chicken
# 1              The Perfect Run
# 2  Kairos: A Greek Myth LitRPG
# 3                 Vigor Mortis
# 4   A Journey of Black and Red
#
#                                                 tags  followers  rating  \
# 0  [adventure, comedy, fantasy, romance, male, ma...      13806    4.83
# 1  [adventure, comedy, mystery, sci-fi, anti-hero...       8613    4.79
# 2  [action, adventure, fantasy, anti-hero, high, ...       3042    4.82
# 3  [adventure, fantasy, horror, female, high, fan...       4931    4.78
# 4  [action, adventure, fantasy, historical, femal...       6420    4.73
#
#    pages    views  chapters date_last_updated
# 0    476  2623581        68        2021-03-29
# 1    791  1421991        68        2021-03-27
# 2    157    92442        12        2021-03-27
# 3    380   376463        35        2021-03-29
# 4   2006  1608082       107        2021-03-26

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2599 entries, 0 to 2716
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              2599 non-null   object
#  1   tags               2599 non-null   object
#  2   followers          2599 non-null   int64
#  3   rating             2599 non-null   float64
#  4   pages              2599 non-null   int64
#  5   views              2599 non-null   int64
#  6   chapters           2599 non-null   int64
#  7   date_last_updated  2599 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(4), object(2)
# memory usage: 182.7+ KB

# %%
df.describe()
# Out:
#           followers       rating         pages         views     chapters
# count   2599.000000  2599.000000   2599.000000  2.599000e+03  2599.000000
# mean     337.457868     3.154025    350.980762  1.759694e+05    38.285494
# std     1160.623637     1.961020    891.281064  1.490847e+06    79.716395
# min        0.000000     0.000000      0.000000  0.000000e+00     1.000000
# 25%        3.000000     0.000000     31.000000  1.650000e+02     5.000000
# 50%       13.000000     4.120000    109.000000  1.333000e+03    15.000000
# 75%       87.000000     4.580000    326.000000  1.860050e+04    40.500000
# max    15766.000000     5.000000  26493.000000  5.339158e+07  1529.000000

# %%
# Fix columns data types
df['date_last_updated'] = pd.to_datetime(df.date_last_updated)
df['followers'] = pd.to_numeric(df.followers)
df['rating'] = pd.to_numeric(df.rating)
df['chapters'] = pd.to_numeric(df.chapters)
df['views'] = pd.to_numeric(df.views)
df['pages'] = pd.to_numeric(df.pages)

# %%
# Check for dubpicate and remove them 
df = df[~df.duplicated()]

# %%
### Exlore the Tags Column
tag_dic = dict()

for tag in df.tags:
    tag = tag.lower()
    for t in tag.split(' '):
        if t not in tag_dic:
            tag_dic[t] = 0
        tag_dic[t] += 1

discardable = ['Arts', 'Portal', '', 'Heroes', 'Travel', 'Ruling', 'Characters', 'lead', 'Reality', 'MC', 'Identity'
'Military', 'of', 'and', 'Intelligence', 'Post', 'Gender', 'Space', 'First', 'Reader', 'Story', 'Lead']

# %%
# Sort dictionary 
tag_dic = dict(sorted(tag_dic.items(), key=lambda item: item[1], reverse=True))
# Get only useful tags and remove labels and values 
keys = []
values = []
for key, value in tag_dic.items():
    if key not in discardable:
        keys.append(key)
        values.append(value)

# %%
fig, ax = plt.subplots(figsize = (10, 14))

ax.barh(y = keys, width = values)
ax.set_ylabel('Gener')
ax.set_xlabel('Freq')
ax.set_title('Gener Frequency')
plt.tight_layout()

# %%
# Copy data frame
df_copy = df.copy()

# %%
# Make Tags into words list
def tags_to_words_lst(x):
    tags = x.lower()
    
    n_list = []
    for tag in tags.split(' '):
        if tag in keys: 
            n_list.append(tag)
            

    return n_list
    
            

df['tags'] = df.tags.apply(lambda x:  tags_to_words_lst(x))
df.head()

# %%
# Explore nnumerical data 
fig, axs = plt.subplots(2, 3, figsize = (13, 6))

numeric_column=['views', 'rating', 'chapters', 'pages', 'followers']

for i, ax in enumerate(axs.flatten()):
    ax.hist(x = df[numeric_column[i]])
    #ax.set_xlabel(column[i])
    ax.set_ylabel('frequency')
    ax.set_title(numeric_column[i])
    if i == 4: break
fig.tight_layout()

# %%
# make new columns 
tags = set()
for ts in df.tags.to_list():
    for t in ts:
        tags.add(t)

tags = list(tags) 
for tag in tags: 
    df[tag] = df['tags'].apply(lambda x: 1 if tag in x else 0)

# %% [markdown]
# # Explore saved file

# %%
# Imports 
import numpy as np

# %%
df = pd.read_pickle('../data/titles.pkl')

# %%
# Explore numeric variables by rating 
fig, axs = plt.subplots(2, 2, figsize = (10, 6))

# columns 
column=['views', 'chapters', 'pages', 'followers']

for i, ax in enumerate(axs.flatten()):
    ax.scatter(x = df['rating'] , y = df[column[i]], alpha = 0.5)
    ax.set_title(f'rating vs {column[i]}')
    ax.set_xlabel('rating')
    ax.set_ylabel(column[i])

plt.tight_layout()

# %%
# Explore numeric variables by rating 
fig, axs = plt.subplots(3, 2, figsize = (10, 6))

# columns 
column = list(df[tags].sum().nlargest(6).keys())

for i, ax in enumerate(axs.flatten()):
    ax.scatter(x = df['rating'] , y = df[column[i]], alpha = 0.5)
    ax.set_title(f'rating vs {column[i]}')
    ax.set_xlabel('rating')
    ax.set_ylabel(column[i])

plt.tight_layout()

# %%
df.head().T
# Out:
#                                                              0  \
# title                                        Beware Of Chicken
# tags         [adventure, comedy, fantasy, romance, male, ma...
# followers                                                13806
# rating                                                    4.83
# pages                                                      476
# ...                                                        ...
# interactive                                                  0
# short                                                        0
# story                                                        0
# hard                                                         0
# sports                                                       0
#
#                                                              1  \
# title                                          The Perfect Run
# tags         [adventure, comedy, mystery, sci-fi, anti-hero...
# followers                                                 8613
# rating                                                    4.79
# pages                                                      791
# ...                                                        ...
# interactive                                                  0
# short                                                        0
# story                                                        0
# hard                                                         0
# sports                                                       0
#
#                                                              2  \
# title                              Kairos: A Greek Myth LitRPG
# tags         [action, adventure, fantasy, anti-hero, high, ...
# followers                                                 3042
# rating                                                    4.82
# pages                                                      157
# ...                                                        ...
# interactive                                                  0
# short                                                        0
# story                                                        0
# hard                                                         0
# sports                                                       0
#
#                                                              3  \
# title                                             Vigor Mortis
# tags         [adventure, fantasy, horror, female, high, fan...
# followers                                                 4931
# rating                                                    4.78
# pages                                                      380
# ...                                                        ...
# interactive                                                  0
# short                                                        0
# story                                                        0
# hard                                                         0
# sports                                                       0
#
#                                                              4
# title                               A Journey of Black and Red
# tags         [action, adventure, fantasy, historical, femal...
# followers                                                 6420
# rating                                                    4.73
# pages                                                     2006
# ...                                                        ...
# interactive                                                  0
# short                                                        0
# story                                                        0
# hard                                                         0
# sports                                                       0
#
# [91 rows x 5 columns]

# %%
list(df[tags].sum().nlargest(6).keys())
# Out:
# ['fantasy',
#  'adventure',
#  'action',
#  'magic',
#  'male',
#  'high',
#  'strong',
#  'female',
#  'supernatural',
#  'characters']
